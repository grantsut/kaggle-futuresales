# %% [markdown]
# # Data loading and preprocessing, utility function definition

# %% [markdown]
# ## Imports and data loading

# %%
import gc
import itertools
import time

import numpy as np
import pandas as pd
import seaborn as sns
from IPython.core.debugger import set_trace
from pandas.tseries.offsets import MonthEnd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import lightgbm as lgbm
# A few functions are imported from a utility script, have a look at it if you like.
import futuresalesutility as fu

# %% [markdown]
# Load the data and convert the date column in the training data to the datetime dtype to enable datetime operations.

# %%
item_categories_extra = pd.read_csv('../input/predict-future-sales-extra/item_categories_enhanced.csv')
item_categories_extra = item_categories_extra.drop(columns=['category_name', 'supercategory', 'platform'])
items = pd.read_csv("../input/competitive-data-science-predict-future-sales/items.csv")
shops = pd.read_csv("../input/competitive-data-science-predict-future-sales/shops.csv")
train = pd.read_csv("../input/competitive-data-science-predict-future-sales/sales_train.csv")
test = pd.read_csv("../input/competitive-data-science-predict-future-sales/test.csv")

train["date"] = pd.to_datetime(train["date"], format="%d.%m.%Y")

# %% [markdown]
# Duplicate removal procedure from Luke M

# %%
#load items_en
items_en = pd.read_csv('../input/future-sales-translated/items.csv')

#clean item_name
items_en['item_name'] = items_en['item_name'].str.lower()
items_en['item_name'] = items_en['item_name'].str.replace('.', '')
for i in [r'[^\w\d\s\.]', r'\bthe\b', r'\bin\b', r'\bis\b',
          r'\bfor\b', r'\bof\b', r'\bon\b', r'\band\b',  
          r'\bto\b', r'\bwith\b' , r'\byo\b']:
    items_en['item_name'] = items_en['item_name'].str.replace(i, ' ')
items_en['item_name'] = items_en['item_name'].str.replace(r'\b.\b', ' ')

#extract first n characters of name
items_en['item_name_no_space'] = items_en['item_name'].str.replace(' ', '')

dupes = items_en[(items_en.duplicated(subset=['item_name','category_id'],keep=False))]
dupes['in_test'] = dupes.item_id.isin(test.item_id.unique())
dupes = dupes.groupby('item_name').agg({'item_id':['first','last'],'in_test':['first','last']})

#if both item id's are in the test set do nothing
dupes = dupes[(dupes[('in_test', 'first')]==False) | (dupes[('in_test', 'last')]==False)]
#if only the first id is in the test set assign this id to both
temp = dupes[dupes[('in_test', 'first')]==True]
keep_first = dict(zip(temp[('item_id', 'last')], temp[('item_id',  'first')]))
#if neither id or only the second id is in the test set, assign the second id to both
temp = dupes[dupes[('in_test', 'first')]==False]
keep_second = dict(zip(temp[('item_id', 'first')], temp[('item_id',  'last')]))
item_map = {**keep_first, **keep_second} # use this as a replace function
train['item_id'] = train['item_id'].replace(item_map)
del temp, items_en, dupes, keep_first, keep_second, i
# Out:
# <ipython-input-3-b4488afb1851>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   items_en['item_name'] = items_en['item_name'].str.replace('.', '')
# <ipython-input-3-b4488afb1851>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   items_en['item_name'] = items_en['item_name'].str.replace(i, ' ')
# <ipython-input-3-b4488afb1851>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   items_en['item_name'] = items_en['item_name'].str.replace(r'\b.\b', ' ')
# <ipython-input-3-b4488afb1851>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dupes['in_test'] = dupes.item_id.isin(test.item_id.unique())

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# * Correct duplicate shop names
# * Drop a few duplicate items in the training set
# * Drop shops which are not in the test set (these are only a few of these and they tend to be strange in some way, e.g. low sales, not operating for long)+
# * Drop categories 8 and 80 as these are for tickets to an annual exhibition which are not sold in the test month
# * Remove outliers and negative values for the item_cnt_day and item_price features (these are few in number but cause problems when generating some features)

# %%
# Correct shop labels
train.loc[train.shop_id == 0, "shop_id"] = 57
train.loc[train.shop_id == 1, "shop_id"] = 58
train.loc[train.shop_id == 11, "shop_id"] = 10
# Drop shops not in test set
testshops = test.shop_id.unique()
train = train.loc[train["shop_id"].isin(testshops), :]
del testshops
# Drop duplicates
train = train.drop_duplicates()
# Drop categories 8 and 80
train = train.merge(items[["item_id", "item_category_id"]], on="item_id", how="left")
train = train[~train.item_category_id.isin([8, 80])]
# Clip outliers and  remove items with a negative sales price or item_cnt_day
train = train.query("(item_price>0) & (item_cnt_day>0)")
train.loc[:, "item_price"] = train.loc[:, "item_price"].clip(0, train["item_price"].quantile(0.9999))
train.loc[:, "item_cnt_day"] = train.loc[:, "item_cnt_day"].clip(0, train["item_cnt_day"].quantile(0.999))

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Create a training matrix similar to the test items by aggregating the sales to the month level and creating items for every possible combination of shops and items featured in each individual month of the training data. Additionally, concatenate test to train data to enable creation of features for the test items.

# %%
def create_testlike_train(sales_train, test=None):
    # Create a date_block_num / item_id / shop_id index using all combinations of item_id and shop_id occurring within each date_block
    # Optionally concatenate the test items to the end
    indexlist = []
    for i in sales_train.date_block_num.unique():
        x = itertools.product(
            [i],
            sales_train.loc[sales_train.date_block_num == i].shop_id.unique(),
            sales_train.loc[sales_train.date_block_num == i].item_id.unique(),
        )
        indexlist.append(np.array(list(x)))
    df = pd.DataFrame(
        data=np.concatenate(indexlist, axis=0), columns=["date_block_num", "shop_id", "item_id"],
    )

    # Add revenue column to sales_train
    sales_train["item_revenue_day"] = sales_train["item_price"] * sales_train["item_cnt_day"]
    # Aggregate item_id / shop_id item_cnts and revenue at the month level
    sales_train_grouped = sales_train.groupby(["date_block_num", "shop_id", "item_id"]).agg(
        item_cnt_month=pd.NamedAgg(column="item_cnt_day", aggfunc="sum"),
        item_revenue_month=pd.NamedAgg(column="item_revenue_day", aggfunc="sum"),
    )

    # Merge the grouped data with the index
    df = df.merge(sales_train_grouped, how="left", on=["date_block_num", "shop_id", "item_id"],)

    if test is not None:
        test["date_block_num"] = 34
        test["date_block_num"] = test["date_block_num"].astype(np.int8)
        test["shop_id"] = test.shop_id.astype(np.int8)
        test["item_id"] = test.item_id.astype(np.int16)
        test = test.drop(columns="ID")

        df = pd.concat([df, test[["date_block_num", "shop_id", "item_id"]]])

    # Fill empty item_cnt entries with 0
    df.item_cnt_month = df.item_cnt_month.fillna(0)
    df.item_revenue_month = df.item_revenue_month.fillna(0)

    return df

# %%
matrix = create_testlike_train(train, test)
matrix = fu.reduce_mem_usage(matrix, silent=False)
oldcols = matrix.columns
# Out:
# Memory usage of dataframe is 401.22 MB
# Memory usage after optimization is: 150.46 MB
# Decreased by 62.5%

# %% [markdown]
# # Feature engineering
# In this section predictor feature columns are generated and added to the matrix

# %% [markdown]
# ## Time features
# Time-dependent features
# * Item and shop age in months
# * Binary features for new items and shops (i.e. first month of appearance)
# * Item and shop age in days
# * Number of days in the current month
# * Average item count per day in the last month - useful for new items which may not have been available for the full calendar month
# * Days since last sale of an item in each shop and all shops

# %%
def add_time_features(m, train, correct_item_cnt_day=False):
    from pandas.tseries.offsets import Day, MonthBegin, MonthEnd

    def item_shop_age_months(m):
        m["item_age"] = m.groupby("item_id")["date_block_num"].transform(lambda x: x - x.min())
        # Sales tend to plateau after 12 months
        m["item_age_max_12"] = m["item_age"].clip(upper=12)
        m["new_item"] = m["item_age"] == 0
        m["new_item"] = m["new_item"].astype("int8")
        m["shop_age"] = m.groupby("shop_id")["date_block_num"].transform(lambda x: x - x.min()).astype("int8")
        m["new_shop"] = m.shop_age == 0
        m["new_shop"] = m["new_shop"].astype("int8")
        return m

    # Add dummy values for the test month so that features are created correctly
    dummies = m.loc[m.date_block_num == 34, ["date_block_num", "shop_id", "item_id"]]
    dummies = dummies.assign(date=pd.to_datetime("2015-11-30"), item_price=1, item_cnt_day=0, item_revenue_day=0,)
    train = pd.concat([train, dummies])
    del dummies

    month_last_day = train.groupby("date_block_num").date.max().rename("month_last_day")
    month_last_day[~month_last_day.dt.is_month_end] = month_last_day[~month_last_day.dt.is_month_end] + MonthEnd()
    month_first_day = train.groupby("date_block_num").date.min().rename("month_first_day")
    month_first_day[~month_first_day.dt.is_month_start] = month_first_day[~month_first_day.dt.is_month_start] - MonthBegin()
    month_length = (month_last_day - month_first_day + Day()).rename("month_length")
    first_shop_date = train.groupby("shop_id").date.min().rename("first_shop_date")
    first_item_date = train.groupby("item_id").date.min().rename("first_item_date")
    first_shop_item_date = train.groupby(["shop_id", "item_id"]).date.min().rename("first_shop_item_date")

    m = m.merge(month_first_day, left_on="date_block_num", right_index=True, how="left")
    m = m.merge(month_last_day, left_on="date_block_num", right_index=True, how="left")
    m = m.merge(month_length, left_on="date_block_num", right_index=True, how="left")
    m = m.merge(first_shop_date, left_on="shop_id", right_index=True, how="left")
    m = m.merge(first_item_date, left_on="item_id", right_index=True, how="left")
    m = m.merge(first_shop_item_date, left_on=["shop_id", "item_id"], right_index=True, how="left")

    # Calculate how long the item was sold for in each month and use this to calculate average sales per day
    m["shop_open_days"] = m["month_last_day"] - m["first_shop_date"] + Day()
    m["item_first_sale_days"] = m["month_last_day"] - m["first_item_date"] + Day()
    m["item_in_shop_days"] = m[["shop_open_days", "item_first_sale_days", "month_length"]].min(axis=1).dt.days
    m = m.drop(columns="item_first_sale_days")
    m["item_cnt_day_avg"] = m["item_cnt_month"] / m["item_in_shop_days"]
    m["month_length"] = m["month_length"].dt.days

    # Calculate the time differences from the beginning of the month so they can be used as features without lagging
    m["shop_open_days"] = m["month_first_day"] - m["first_shop_date"]
    m["first_item_sale_days"] = m["month_first_day"] - m["first_item_date"]
    m["first_shop_item_sale_days"] = m["month_first_day"] - m["first_shop_item_date"]
    m["shop_open_days"] = m["shop_open_days"].dt.days.fillna(0).clip(lower=0)
    m["first_item_sale_days"] = m["first_item_sale_days"].dt.days.fillna(0).clip(lower=0)
    m["first_shop_item_sale_days"] = m["first_shop_item_sale_days"].dt.days.fillna(0).clip(lower=0)

    # Change the first sale date feature to integer format indexed from the first day in the training data
    m["first_day"] = train.date.min()
    m["first_item_date"] = (m["first_item_date"] - m["first_day"]).dt.days
    m["first_shop_item_date"] = (m["first_shop_item_date"] - m["first_day"]).dt.days

    # Add days since last sale
    def last_sale_days(matrix):
        last_shop_item_dates = []
        last_item_dates = []
        for dbn in tqdm(range(1, 35)):
            lsid_temp = train.query(f"date_block_num<{dbn}").groupby(["shop_id", "item_id"]).date.max().rename("last_shop_item_sale_date").reset_index()
            lid_temp = lsid_temp.groupby("item_id").last_shop_item_sale_date.max().rename("last_item_sale_date").reset_index()
            lsid_temp["date_block_num"] = dbn
            lid_temp["date_block_num"] = dbn
            last_shop_item_dates.append(lsid_temp)
            last_item_dates.append(lid_temp)
        last_shop_item_dates = pd.concat(last_shop_item_dates)
        last_item_dates = pd.concat(last_item_dates)
        matrix = matrix.merge(last_shop_item_dates, on=["date_block_num", "shop_id", "item_id"], how="left")
        matrix = matrix.merge(last_item_dates, on=["date_block_num", "item_id"], how="left")

        def days_since_last_feat(m, feat_name, date_feat_name, missingval):
            m[feat_name] = (m["month_first_day"] - m[date_feat_name]).dt.days
            m.loc[m[feat_name] > 2000, feat_name] = missingval
            m.loc[m[feat_name].isna(), feat_name] = missingval
            return m

        matrix = days_since_last_feat(matrix, "last_shop_item_sale_days", "last_shop_item_sale_date", 9999)
        matrix = days_since_last_feat(matrix, "last_item_sale_days", "last_item_sale_date", 9999)
        matrix = matrix.drop(columns=["last_shop_item_sale_date", "last_item_sale_date"])
        return matrix

    m = last_sale_days(m)
    # Month
    m["month"] = m["month_first_day"].dt.month

    m = m.drop(
        columns=["first_day", "month_first_day", "month_last_day", "first_shop_date", "first_item_date", "item_in_shop_days", "first_shop_item_date",],
        errors="ignore",
    )

    m = item_shop_age_months(m)

    if correct_item_cnt_day == True:
        m["item_cnt_month_original"] = m["item_cnt_month"]
        m["item_cnt_month"] = m["item_cnt_day_avg"] * m["month_length"]

    return m

# %%
matrix = add_time_features(matrix, train, False)
print("Time features created")
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Time features created

# %% [markdown]
# Additionally clip the corrected monthly item counts to remove the effect of outliers, but save the unclipped version for use as a feature.

# %%
matrix['item_cnt_month_unclipped'] = matrix.loc[:,'item_cnt_month']
matrix['item_cnt_month'] = matrix['item_cnt_month'].clip(lower=0, upper=20)

# %% [markdown]
# ## Price features
# * Last mean price for a month in which the item was sold
# * Difference of the last price from the historical mean (calculated with an expanding window)
# * Difference of the last mean price from the first sale price in the data (proxy for the release price)
# * Difference of the last mean price from the mean for the category in the same month.
#
# It can be assumed that item price is related to sales, both in absolute terms and relative to other items of the same category and the same item's earlier price.

# %%
def add_price_features(matrix, train):
    # Get mean prices per month from train dataframe
    price_features = train.groupby(["date_block_num", "item_id"]).item_price.mean()
    price_features = pd.DataFrame(price_features)
    price_features = price_features.reset_index()
    # Calculate expanding mean and join to dataframe
    emp = price_features.groupby("item_id").item_price.expanding().mean()
    emp = emp.reset_index(level=0)
    price_features["exp_mean_price"] = emp["item_price"]
    del emp
    # Get first sale price for item
    price_features["start_price"] = price_features.groupby(
        "item_id"
    ).item_price.transform(lambda x: x.to_numpy()[0])
    # Calculate  differences from start and mean prices
    price_features["norm_diff_exp_mean_price"] = (
        price_features["item_price"] - price_features["exp_mean_price"]
    ) / price_features["exp_mean_price"]
    price_features["norm_diff_start_price"] = (
        price_features["item_price"] - price_features["start_price"]
    ) / price_features["start_price"]
    # Calculate normalized differences from start and mean prices
    price_features["norm_diff_exp_mean_price"] = (
        price_features["item_price"] - price_features["exp_mean_price"]
    ) / price_features["exp_mean_price"]
    # Calculate normalized differenced from mean category price per month
    price_features = price_features.merge(
        items[["item_id", "item_category_id"]], how="left", on="item_id"
    )
    price_features["norm_diff_cat_price"] = price_features.groupby(
        ["date_block_num", "item_category_id"]
    )["item_price"].transform(lambda x: (x - x.mean()) / x.mean())
    # Retain only the necessary features
    price_features = price_features[
        [
            "date_block_num",
            "item_id",
            "item_price",
            "norm_diff_exp_mean_price",
            "norm_diff_start_price",
            "norm_diff_cat_price",
        ]
    ]

    features = [
        "item_price",
        "norm_diff_exp_mean_price",
        "norm_diff_start_price",
        "norm_diff_cat_price",
    ]
    newnames = ["last_" + f for f in features]
    aggs = {f: "last" for f in features}
    renames = {f: "last_" + f for f in features}

    features = []
    for dbn in tqdm(range(1, 35)):
        f_temp = (
            price_features.query(f"date_block_num<{dbn}")
            .groupby("item_id")
            .agg(aggs)
            .rename(columns=renames)
        )
        f_temp["date_block_num"] = dbn
        features.append(f_temp)
    features = pd.concat(features).reset_index()

    matrix = matrix.merge(features, on=["date_block_num", "item_id"], how="left")
    matrix[newnames] = matrix[newnames].fillna(999999)
    return matrix


matrix = add_price_features(matrix, train)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=34.0), HTML(value='')))

# %% [markdown]
# ## Categorical features

# %% [markdown]
# Categorical features provided with the data, e.g. item category, and custom categories extracted from category and shop names, e.g. "video games", "music", "PS4"

# %%
matrix = matrix.merge(items.drop(columns='item_name'), on='item_id', how='left')
matrix = matrix.merge(item_categories_extra, on='item_category_id', how='left')

# %% [markdown]
# City that the shop is located in
# (from https://www.kaggle.com/dlarionov/feature-engineering-xgboost)

# %%
def add_city_codes(matrix, shops):
    shops.loc[
        shops.shop_name == 'Сергиев Посад ТЦ "7Я"', "shop_name"
    ] = 'СергиевПосад ТЦ "7Я"'
    shops["city"] = shops["shop_name"].str.split(" ").map(lambda x: x[0])
    shops.loc[shops.city == "!Якутск", "city"] = "Якутск"
    shops["city_code"] = shops["city"].factorize()[0]
    shop_labels = shops[["shop_id", "city_code"]]
    matrix = matrix.merge(shop_labels, on='shop_id', how='left')
    return matrix

matrix = add_city_codes(matrix, shops)

# %%
gc.collect()
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)  # Use this function periodically to downcast dtypes to save memory
# matrix.to_pickle("matrixcheckpoint_1.pk1")
print("Saved matrixcheckpoint 1")
# Out:
# Saved matrixcheckpoint 1

# %% [markdown]
# ## Rolling mean features
# Sales from previous months are a good predictor of future sales, but chance fluctuations mean that an average of several previous months may be more reliable than counts from a single month. Pandas has several windowing functions for time series built in, 3 of which are demonstrated below : expanding (all previous timepoints), rolling (a fixed number of previous timepoints) and exponential (a weighted window with weights which decrease with time distance before the current point). These are compared below.

# %%
shop_id = 16
item_id = 482
im = matrix.query(f"shop_id=={shop_id} & item_id=={item_id}")[['date_block_num', 'item_cnt_month']]
im['moving average'] = im['item_cnt_month'].ewm(halflife=1).mean()
im['expanding mean'] = im['item_cnt_month'].expanding().mean()
im['rolling 12 month mean'] = im['item_cnt_month'].rolling(window=12, min_periods=1).mean()
im = im.set_index('date_block_num')
ax = im.plot(figsize=(12,5), marker='.', title='Time series averaging methods')

# %% [markdown]
# A weakness of the pandas windowed functions is that they do not insert zeros for missing timepoints and our data matrix does not contain entries for month in which items were not sold.
# This is solved here by creating a sales matrix which contains entries for all items in all months, and using this to generate windowed features. Entries for months prior to an items availability are set to NaN so that they are not included in calculations.
# Because of the high memory requirements of the functions and dataframes used to create windowed features, these functions are created early in the script before the feature dataframe has grown larger.

# %%
def create_full_train_test(sales_train, test, clip_target=20.0):
    # Create a train set with all items and all shops in all date blocks.
    # Add revenue column to sales_train
    sales_train["item_revenue_day"] = sales_train["item_price"] * sales_train["item_cnt_day"]
    # Aggregate item_id / shop_id item_cnts and revenue at the month level
    sales_train_grouped = sales_train.groupby(["date_block_num", "shop_id", "item_id"]).agg(
        item_cnt_month=pd.NamedAgg(column="item_cnt_day", aggfunc="sum"),
        item_revenue_month=pd.NamedAgg(column="item_revenue_day", aggfunc="sum"),
    )
    # Create sets of items, shops and date blocks
    item_ids = set(sales_train.item_id).union(set(test.item_id))
    shop_ids = set(sales_train.shop_id).union(set(test.shop_id))
    date_block_nums = set(sales_train.date_block_num).union(set([34]))
    # Create all permutations as indexes
    indexdataframe = pd.DataFrame(
        np.array(list(itertools.product(date_block_nums, item_ids, shop_ids))),
        columns=["date_block_num", "item_id", "shop_id"],
    )
    m = indexdataframe.merge(sales_train_grouped, how="left", on=["date_block_num", "item_id", "shop_id"])
    m.item_cnt_month = m.item_cnt_month.fillna(0)
    m.item_revenue_month = m.item_revenue_month.fillna(0)
    shop_first_sales = train.groupby("shop_id").date_block_num.min().rename("shop_first_month")
    shop_last_sales = train.groupby("shop_id").date_block_num.max().rename("shop_last_month")
    item_first_sales = train.groupby("item_id").date_block_num.min().rename("item_first_month")
    m = m.merge(shop_first_sales, on="shop_id", how="left")
    m = m.merge(shop_last_sales, on="shop_id", how="left")
    m = m.merge(item_first_sales, on="item_id", how="left")
    mask = (
        (m.date_block_num < m.shop_first_month)
        | (m.date_block_num < m.item_first_month)
        | (m.date_block_num > m.shop_last_month)
    )
    m = m.drop(columns=["shop_first_month", "shop_last_month", "item_first_month"])
    m.loc[mask, ["item_cnt_month", "item_revenue_month"]] = np.nan
    
    if clip_target is not None:
        m['item_cnt_month'] = m['item_cnt_month'].clip(upper=clip_target)
    m = fu.reduce_mem_usage(m)
    return m

# %%
m = create_full_train_test(train, test)

# %%
m = add_time_features(m, train, False)
m = m[['date_block_num', 'item_id', 'shop_id', 'item_cnt_month', 'item_revenue_month', 'item_cnt_day_avg']]
gc.collect()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=34.0), HTML(value='')))
# 46

# %%
m[['item_cnt_month', 'item_cnt_day_avg']].isna().sum()
# Out:
# item_cnt_month      9735309
# item_cnt_day_avg    9735309
# dtype: int64

# %%
def add_rolling_ME(
    # General purpose windowed aggregation function
    matrix,
    features,
    window=3,
    min_periods=1,
    kind="rolling",
    source_matrix=None,
    target_feature="item_cnt_month",
    aggregation="mean",
    rolling_aggregation="mean",
):
    """Add a rolling mean item_cnt_month feature for a specificed categorical feature
    or features. Calculates using the feature matrix and therefore does not insert zeros
    for features with zero sales in a specific month (use feature specific rolling ME
    functions for rolling item or item-shop features)"""
    features = fu.list_if_not(features)
    if source_matrix is None:
        source_matrix = matrix
    im = source_matrix.groupby(features + ["date_block_num"])[target_feature].agg(aggregation)
    im = im.reset_index(level=features + ["date_block_num"])
    im = fu.reduce_mem_usage(im)
    if kind=="ewm":
        feat_name = f"{'_'.join(features)}_{target_feature}_{aggregation}_ewm_hl_{window}"
        print(f'Creating feature "{feat_name}"')
        im[feat_name] = im.groupby(features)[target_feature].transform(lambda x: x.ewm(halflife=window, min_periods=min_periods).mean())
    elif kind=="expanding":
        feat_name = f"{'_'.join(features)}_{target_feature}_{aggregation}_expanding_{rolling_aggregation}"
        print(f'Creating feature "{feat_name}"')
        im[feat_name] = im.groupby(features)[target_feature].transform(lambda x: x.expanding(min_periods=min_periods).aggregate(rolling_aggregation))
    elif kind=="rolling":
        feat_name = (
            f"{'_'.join(features)}_{target_feature}_{aggregation}_rolling_{rolling_aggregation}_win_{window}"
        )
        print(f'Creating feature "{feat_name}"')
        im[feat_name] = im.groupby(features)[target_feature].transform(lambda x: x.rolling(window=window, min_periods=min_periods).aggregate(rolling_aggregation))
    im = im.drop(columns=target_feature)
    im.loc[:, 'date_block_num'] += 1
    matrix = matrix.merge(im, on=['date_block_num'] + features, how='left')
    matrix[feat_name] = matrix[feat_name].fillna(0)
    # High valued missing value marker for new items
    if "item_id" in features:
        matrix.loc[matrix.new_item==True, feat_name] = 9999
    return matrix

# %% [markdown]
# Implement rolling mean / median / minimum / maximum features.
#
# Create features using the full sales matrix first.

# %%
matrix = add_rolling_ME(matrix, ["shop_id", "item_id"], window=12, source_matrix=m)
gc.collect()
matrix = add_rolling_ME(matrix, ["shop_id", "item_id"], window=1, kind="ewm", source_matrix=m, aggregation="median")
gc.collect()
matrix = add_rolling_ME(matrix, ["shop_id", "item_id"], window=1, kind="ewm", source_matrix=m, target_feature='item_cnt_day_avg', aggregation="median")
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=12, source_matrix=m)
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=1, kind="ewm", source_matrix=m)
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=12, target_feature="item_revenue_month", aggregation="sum", source_matrix=m,)
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=12, source_matrix=m, aggregation="median")
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=1, kind="ewm", source_matrix=m, aggregation="median")
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=12, source_matrix=m, aggregation="var")
gc.collect()
matrix = add_rolling_ME(matrix, ["item_id"], window=1, kind="ewm", source_matrix=m, target_feature='item_cnt_day_avg')
gc.collect()
del m
# Out:
# Creating feature "shop_id_item_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "shop_id_item_id_item_cnt_month_median_ewm_hl_1"
# Creating feature "shop_id_item_id_item_cnt_day_avg_median_ewm_hl_1"
# Creating feature "item_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "item_id_item_cnt_month_mean_ewm_hl_1"
# Creating feature "item_id_item_revenue_month_sum_rolling_mean_win_12"
# Creating feature "item_id_item_cnt_month_median_rolling_mean_win_12"
# Creating feature "item_id_item_cnt_month_median_ewm_hl_1"
# Creating feature "item_id_item_cnt_month_var_rolling_mean_win_12"
# Creating feature "item_id_item_cnt_day_avg_mean_ewm_hl_1"

# %%
# Rolling sum features that are later used to create rolling item_cnt_day features
matrix = add_rolling_ME(matrix, ["shop_id", "item_id"], target_feature="item_cnt_month", aggregation="sum", rolling_aggregation="sum", kind="rolling", window=12)
matrix = add_rolling_ME(matrix, ["item_id"], target_feature="item_cnt_month", aggregation="sum", rolling_aggregation="sum", kind="rolling", window=12)
# Item category rolling features
matrix = add_rolling_ME(matrix, ["item_category_id"], window=12)
matrix = add_rolling_ME(matrix, ["supercategory_id"], window=12)
matrix = add_rolling_ME(matrix, ["new_item", "item_category_id"], window=12)
matrix = add_rolling_ME(matrix, ["new_item", "supercategory_id"], window=12)
matrix = add_rolling_ME(matrix, ["new_item", "item_category_id"], window=1, kind="ewm")
matrix = add_rolling_ME(matrix, ["new_item", "item_category_id"], window=12, aggregation="median")
matrix = add_rolling_ME(matrix, ["shop_id", "item_category_id"], window=12)
matrix = add_rolling_ME(matrix, ["shop_id", "supercategory_id"], window=12)
matrix = add_rolling_ME(matrix, ["shop_id", "item_category_id"], window=1, kind="ewm")
matrix = add_rolling_ME(matrix, ["city_code", "item_category_id"], window=12)
matrix = add_rolling_ME(matrix, ["city_code", "item_category_id"], window=1, kind="ewm")
gc.collect()
# Shop-related features
matrix = add_rolling_ME(matrix, ["shop_id"], window=12)
matrix = add_rolling_ME(matrix, ["shop_id"], window=12, target_feature="item_revenue_month", aggregation="sum")
matrix = add_rolling_ME(matrix, ["shop_id", "digital"], window=12)
matrix = add_rolling_ME(matrix, ["shop_id", "item_category_id"], window=1, kind="ewm", aggregation="median")
matrix = add_rolling_ME(matrix, ["shop_id", "item_category_id"], window=12, target_feature="item_cnt_month", aggregation="sum",)
matrix = add_rolling_ME(matrix, ["new_item", "shop_id", "item_category_id"], window=1, kind="ewm")
matrix = add_rolling_ME(matrix, ["new_item", "shop_id", "item_category_id"], window=12)
matrix = add_rolling_ME(matrix, ["new_item", "shop_id", "item_category_id"], window=12, target_feature="item_cnt_month", aggregation="sum",)
# Item price rolling mean
matrix = add_rolling_ME(matrix, ["item_id"], window=1, target_feature="last_item_price", kind="ewm")
gc.collect()
# Out:
# Creating feature "shop_id_item_id_item_cnt_month_sum_rolling_sum_win_12"
# Creating feature "item_id_item_cnt_month_sum_rolling_sum_win_12"
# Creating feature "item_category_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "supercategory_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "new_item_item_category_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "new_item_supercategory_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "new_item_item_category_id_item_cnt_month_mean_ewm_hl_1"
# Creating feature "new_item_item_category_id_item_cnt_month_median_rolling_mean_win_12"
# Creating feature "shop_id_item_category_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "shop_id_supercategory_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "shop_id_item_category_id_item_cnt_month_mean_ewm_hl_1"
# Creating feature "city_code_item_category_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "city_code_item_category_id_item_cnt_month_mean_ewm_hl_1"
# Creating feature "shop_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "shop_id_item_revenue_month_sum_rolling_mean_win_12"
# Creating feature "shop_id_digital_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "shop_id_item_category_id_item_cnt_month_median_ewm_hl_1"
# Creating feature "shop_id_item_category_id_item_cnt_month_sum_rolling_mean_win_12"
# Creating feature "new_item_shop_id_item_category_id_item_cnt_month_mean_ewm_hl_1"
# Creating feature "new_item_shop_id_item_category_id_item_cnt_month_mean_rolling_mean_win_12"
# Creating feature "new_item_shop_id_item_category_id_item_cnt_month_sum_rolling_mean_win_12"
# Creating feature "item_id_last_item_price_mean_ewm_hl_1"
# 0

# %% [markdown]
# Mean item_cnt_day features with day-resolution accuracy

# %%
matrix['1year'] = 365
matrix['shop_id_item_id_item_cnt_day_rolling_mean_win_12'] = matrix["shop_id_item_id_item_cnt_month_sum_rolling_sum_win_12"] / matrix[["first_item_sale_days", "shop_open_days", "1year"]].min(axis=1)
matrix['shop_id_item_id_item_cnt_day_rolling_mean_win_12'] = matrix['shop_id_item_id_item_cnt_day_rolling_mean_win_12'].fillna(0)
matrix.loc[(matrix.new_item==True) | (matrix.new_shop), 'shop_id_item_id_item_cnt_day_rolling_mean_win_12'] = 9999
matrix['item_id_item_cnt_day_allshops_rolling_mean_win_12'] = matrix["item_id_item_cnt_month_sum_rolling_sum_win_12"] / matrix[["first_item_sale_days", "1year"]].min(axis=1)
matrix['item_id_item_cnt_day_allshops_rolling_mean_win_12'] = matrix['item_id_item_cnt_day_allshops_rolling_mean_win_12'].fillna(0)
matrix.loc[matrix.new_item==True, 'item_id_item_cnt_day_allshops_rolling_mean_win_12']
matrix = matrix.drop(columns='1year')

# %% [markdown]
# Expanding window features

# %%
# Expanding sum also functions as a marker of a previous item sale
matrix = add_rolling_ME(matrix, ["shop_id", "item_id"], target_feature="item_cnt_month", aggregation="sum", rolling_aggregation="sum", kind="expanding",)
matrix = add_rolling_ME(matrix, ["item_id"], target_feature="item_cnt_month", aggregation="sum", rolling_aggregation="sum", kind="expanding",)
matrix = add_rolling_ME(matrix, ["item_id"], target_feature="item_revenue_month", aggregation="sum", rolling_aggregation="sum", kind="expanding",)
gc.collect()
# Mean sales of same category features with the same age in past data, using expanding mean
matrix = add_rolling_ME(matrix, ["shop_id", "item_category_id"], kind="expanding")
matrix = add_rolling_ME(matrix, ["item_category_id"], kind="expanding")
# Out:
# Creating feature "shop_id_item_id_item_cnt_month_sum_expanding_sum"
# Creating feature "item_id_item_cnt_month_sum_expanding_sum"
# Creating feature "item_id_item_revenue_month_sum_expanding_sum"
# Creating feature "shop_id_item_category_id_item_cnt_month_mean_expanding_mean"
# Creating feature "item_category_id_item_cnt_month_mean_expanding_mean"

# %%
gc.collect()
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)
matrix.to_pickle("matrixcheckpoint_2.pk1")
print("Saved matrixcheckpoint 2")
# Out:
# Saved matrixcheckpoint 2

# %% [markdown]
# ## Lagged features
# Values for the same shop-item combination from the previous month

# %%
def simple_lag_feature(matrix, lag_feature, lags):
    targetseries = matrix.loc[:,['date_block_num', 'item_id', 'shop_id'] + [lag_feature]]
    targetseries = targetseries.set_index(['date_block_num', 'item_id', 'shop_id'])
    targetseries = targetseries[lag_feature]
    matrix = fu.apply_lags(matrix, targetseries, ['item_id', 'shop_id'], lags)
    return matrix

# %%
matrix = simple_lag_feature(matrix, 'item_cnt_month', lags=[1,2,3])
matrix = simple_lag_feature(matrix, 'item_cnt_month_unclipped', lags=[1])
matrix = simple_lag_feature(matrix, 'item_cnt_day_avg', lags=[1])
matrix = simple_lag_feature(matrix, 'item_revenue_month', lags=[1])
gc.collect()
print("Lag features created")
# Out:
# HBox(children=(HTML(value='Applying lags for item_cnt_month'), FloatProgress(value=0.0, max=3.0), HTML(value='…
# HBox(children=(HTML(value='Applying lags for item_cnt_month_unclipped'), FloatProgress(value=0.0, max=1.0), HT…
# HBox(children=(HTML(value='Applying lags for item_cnt_day_avg'), FloatProgress(value=0.0, max=1.0), HTML(value…
# HBox(children=(HTML(value='Applying lags for item_revenue_month'), FloatProgress(value=0.0, max=1.0), HTML(val…
# Lag features created

# %% [markdown]
# ## Mean encodings
# The mean value of a target feature for each level of a categorical feature or combination of categorical features, lagged

# %%
def create_apply_ME(
    matrix, grouping_fields, name, lags=[1], source_frame=None, target="item_cnt_month", aggregation="mean",
):
    if source_frame is None:
        source_frame = matrix
    grouping_fields = fu.list_if_not(grouping_fields)
    me_series = source_frame.groupby(["date_block_num"] + grouping_fields)[target].agg(aggregation).rename(name)
    matrix = fu.apply_lags(matrix, me_series, grouping_fields, lags)
    return matrix

# %%
matrix = create_apply_ME(matrix, ["item_id"], "item_id_ME", lags=[1])
matrix = create_apply_ME(matrix, ["item_id"], "item_id_item_cnt_day_avg", lags=[1, 2, 3], target="item_cnt_day_avg")
matrix = create_apply_ME(matrix, ["item_id"], "item_id_ME_unclipped", target="item_cnt_month_unclipped")
matrix = create_apply_ME(matrix, ["item_category_id"], "item_category_id_ME", [1, 12])
matrix = create_apply_ME(matrix, ["platform_id"], "platform_id_ME", [1, 12])
matrix = create_apply_ME(matrix, ["shop_id", "item_category_id"], "shop_id_item_category_id_ME", [1])
matrix = create_apply_ME(matrix, ["shop_id", "digital"], "shop_id_digital_ME", [1])
matrix = create_apply_ME(matrix, ["city_code", "item_id"], "city_code_item_id_item_cnt_day_ME", [1], target="item_cnt_day_avg")
matrix = create_apply_ME(matrix, ["new_item", "item_category_id"], "item_age_item_category_id_ME", [1], target="item_cnt_month")
matrix = create_apply_ME(matrix, ["new_item", "shop_id", "item_category_id"], "new_item_shop_id_item_category_id_ME", [1])
# Out:
# HBox(children=(HTML(value='Applying lags for item_id_ME'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Applying lags for item_id_item_cnt_day_avg'), FloatProgress(value=0.0, max=3.0), HT…
# HBox(children=(HTML(value='Applying lags for item_id_ME_unclipped'), FloatProgress(value=0.0, max=1.0), HTML(v…
# HBox(children=(HTML(value='Applying lags for item_category_id_ME'), FloatProgress(value=0.0, max=2.0), HTML(va…
# HBox(children=(HTML(value='Applying lags for platform_id_ME'), FloatProgress(value=0.0, max=2.0), HTML(value='…
# HBox(children=(HTML(value='Applying lags for shop_id_item_category_id_ME'), FloatProgress(value=0.0, max=1.0),…
# HBox(children=(HTML(value='Applying lags for shop_id_digital_ME'), FloatProgress(value=0.0, max=1.0), HTML(val…
# HBox(children=(HTML(value='Applying lags for city_code_item_id_item_cnt_day_ME'), FloatProgress(value=0.0, max…
# HBox(children=(HTML(value='Applying lags for item_age_item_category_id_ME'), FloatProgress(value=0.0, max=1.0)…
# HBox(children=(HTML(value='Applying lags for new_item_shop_id_item_category_id_ME'), FloatProgress(value=0.0, …

# %% [markdown]
# ## Ratios between recent sales and rolling 12 month means

# %%
matrix["item_id_item_cnt_1_12_ratio"] = (
    matrix["item_id_ME_lag_1"] / matrix["item_id_item_cnt_month_mean_rolling_mean_win_12"]
).fillna(1)
matrix["item_category_id_item_cnt_lag_1_12_ratio"] = (
    matrix["item_category_id_ME_lag_1"] / matrix["item_category_id_item_cnt_month_mean_rolling_mean_win_12"]
).fillna(1)
matrix["shop_id_item_category_id_item_cnt_lag_1_12_ratio"] = (
    matrix["shop_id_item_category_id_ME_lag_1"]
    / matrix["shop_id_item_category_id_item_cnt_month_mean_rolling_mean_win_12"]
).fillna(1)

# %%
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)
gc.collect()
print("Mean encoding features created")
# Out:
# Mean encoding features created

# %% [markdown]
# ## Percentage change in an aggregate feature over a specified period
# e.g. change in total shop revenue compared to the previous month

# %%
def add_pct_change(
    df, group_feats, quantity="item_cnt_month", agg_function="mean", periods=1, lag=1, clip_value=None,
):
    periods = fu.list_if_not(periods, int)
    group_feats = fu.list_if_not(group_feats)
    group_feats_full = ["date_block_num"] + group_feats
    idx = pd.MultiIndex.from_product([df[col].unique() for col in group_feats_full], names=group_feats_full)
    template = pd.DataFrame(index=idx)
    template = template.sort_index()
    aggs = df.groupby(group_feats_full)[quantity].agg(agg_function).fillna(value=0)
    template = template.merge(aggs, on=group_feats_full, how="left")
    for period in periods:
        feat_name = "_".join(group_feats + [quantity] + [agg_function] + ["delta"] + [str(period)])
        print(f"Adding feature {feat_name}")
        feature_series = (
            template.groupby(group_feats)[quantity]
            .transform(lambda x: x.pct_change(periods=period, fill_method="pad"))
            .fillna(value=0)
            .rename(feat_name)
        )
        if clip_value is not None:
            feature_series = feature_series.clip(lower=-clip_value, upper=clip_value)
        df = fu.add_lag_feature(df, feature_series, group_feats, lag=lag)
    gc.collect()
    return df

# %%
# Mean item price change
matrix = add_pct_change(matrix, ["item_id"], "last_item_price", clip_value=3, lag=0)
# Mean item sales change
matrix = add_pct_change(matrix, ["item_id"], "item_cnt_month", clip_value=3)
# Mean item category sales change
matrix = add_pct_change(matrix, ["item_category_id"], "item_cnt_month", clip_value=3)
# Mean sales change across everything

# %%
matrix = add_pct_change(matrix, ["shop_id", "item_id"], "item_cnt_month", clip_value=3)
# Mean item revenue change
matrix = add_pct_change(matrix, ["item_id"], "item_revenue_month", agg_function="sum", clip_value=3)
# Delta 1 features lagged by 12 months, intended to capture seasonal trends
matrix = add_pct_change(matrix, ["item_category_id"], "item_cnt_month", lag=12, clip_value=3,)
matrix = add_pct_change(matrix, ["shop_id"], "item_cnt_month", lag=12, clip_value=3)
# Mean item sales change measured with item_cnt_day_avg
matrix = add_pct_change(matrix, ["item_id"], "item_cnt_day_avg", clip_value=3)
# Out:
# Adding feature shop_id_item_id_item_cnt_month_mean_delta_1
# Adding feature item_id_item_revenue_month_sum_delta_1
# Adding feature item_category_id_item_cnt_month_mean_delta_1
# Adding feature shop_id_item_cnt_month_mean_delta_1
# Adding feature item_id_item_cnt_day_avg_mean_delta_1

# %%
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)
gc.collect()
print("Delta features created")
# Out:
# Delta features created

# %% [markdown]
# ## Categorical interaction features

# %%
def interaction_feature(matrix, features):
    feature_name = '_'.join(['interaction'] + features)
    matrix[feature_name] = matrix[features[0]].apply(str)
    for feature in features[1:]:
        matrix[feature_name] = matrix[feature_name] + '_' +  matrix[feature].apply(str)
    matrix[feature_name] = fu.reduce_mem_usage(matrix[feature_name], allow_categorical=False)
    return matrix

# %%
# Month category interactions
matrix = interaction_feature(matrix, ["month", "item_category_id"])
matrix = interaction_feature(matrix, ["month", "digital"])

# %% [markdown]
# ## Artist name feature for music categories
#
# The "item_name" field of items in the music categories typically begin with the artist's name marked with one of three patterns: either all uppercase, separated from the release title by a doublespace, or separated by dot-space (. ). Regex expressions are used to extract artist names from music categories using these rules. For non-music categories, the first word in the name is extracted instead.

# %%
items.query("item_category_id==55").head(5)
# Out:
#                                         item_name  item_id  item_category_id
# 12                *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12                55
# 970        30 SECONDS TO MARS  30 Seconds To Mars      970                55
# 971           30 SECONDS TO MARS  A Beautiful Lie      971                55
# 972  30 SECONDS TO MARS  Love Lust Faith + Dreams      972                55
# 975               30 SECONDS TO MARS  This Is War      975                55

# %%
import nltk
# nltk.download("stopwords")
from nltk.corpus import stopwords
import re

def add_name_features(
    matrix, factorize=True, items=items, fillna_value=-99, feature_name="artist_name_or_first_word",
    prune_quantile=0.25
):
    # This extracts artist names for music categories and adds them as a feature.
    def extract_artist(st):

        st = st.strip()
        if st.startswith("V/A"):
            artist = "V/A"
        elif st.startswith("СБ"):
            artist = "СБ"
        else:
            # Retrieves artist names using the double space or all uppercase pattern
            mus_artist_dubspace = re.compile(r".{2,}?(?=\s{2,})")
            match_dubspace = mus_artist_dubspace.match(st)
            mus_artist_capsonly = re.compile(r"^([^a-zа-я]+\s)+")
            match_capsonly = mus_artist_capsonly.match(st)
            candidates = [match_dubspace, match_capsonly]
            candidates = [m[0] for m in candidates if m is not None]
            # Sometimes one of the patterns catches some extra words so choose the shortest one
            if len(candidates):
                artist = min(candidates, key=len)
            else:
                # If neither of the previous patterns found something, use the dot-space pattern
                mus_artist_dotspace = re.compile(r".{2,}?(?=\.\s)")
                match = mus_artist_dotspace.match(st)
                if match:
                    artist = match[0]
                else:
                    artist = ""
        artist = artist.upper()
        artist = re.sub(r"[^A-ZА-Я ]||\bTHE\b", "", artist)
        artist = re.sub(r"\s{2,}", " ", artist)
        artist = artist.strip()
        return artist

    def first_word(string):
        # This cleans the string of special characters, excess spaces and stopwords then extracts the first word
        all_stopwords = stopwords.words("russian")
        all_stopwords = all_stopwords + stopwords.words("english")
        string = re.sub(r"[^\w\s]", "", string)
        string = re.sub(r"\s{2,}", " ", string)
        tokens = string.lower().split()
        tokens = [t for t in tokens if t not in all_stopwords]
        token = tokens[0] if len(tokens) > 0 else ""
        return token

    music_categories = [55, 56, 57, 58, 59, 60]
    items.loc[items.item_category_id.isin(music_categories), feature_name] = items.loc[items.item_category_id.isin(music_categories), "item_name"].apply(
        extract_artist
    )

    items.loc[items[feature_name] == "", feature_name] = "other music"

    items.loc[~items.item_category_id.isin(music_categories), feature_name] = items.loc[~items.item_category_id.isin(music_categories), "item_name"].apply(
        first_word
    )

    items.loc[items[feature_name] == "", feature_name] = "other non-music"

    if factorize:
        items[feature_name] = items[feature_name].factorize(na_sentinel=fillna_value)[0]

    matrix = matrix.merge(items[["item_id", feature_name]], on="item_id", how="left",)
    if fillna_value is not None:
        matrix[feature_name] = matrix[feature_name].fillna(fillna_value)
    
    if prune_quantile>0:  # replace low-occurence words / artists by a category marker
        vc = matrix['artist_name_or_first_word'].value_counts().rename('first_word_vcs')
        matrix = matrix.merge(vc, left_on='artist_name_or_first_word', right_index=True, how='left')
        prune_mask = matrix.first_word_vcs<=matrix['first_word_vcs'].quantile(prune_quantile)
        matrix.loc[prune_mask, 'artist_name_or_first_word'] = -matrix.loc[prune_mask, 'item_category_id']
        matrix = matrix.drop(columns='first_word_vcs')
    return matrix

# %%
matrix = add_name_features(matrix, factorize=True)

# %%
# Music artist rolling mean sale count and revenue
matrix = add_rolling_ME(matrix, ["artist_name_or_first_word"], window=24)
matrix = add_rolling_ME(matrix, ["artist_name_or_first_word", "city_code"], kind="expanding")
matrix = add_rolling_ME(matrix, ["artist_name_or_first_word", "new_item"], kind="expanding")
matrix = add_rolling_ME(
    matrix, ["artist_name_or_first_word"], aggregation="sum", kind="expanding"
)
matrix = add_rolling_ME(
    matrix, ["artist_name_or_first_word"], aggregation="sum", target_feature="item_revenue_month", kind="expanding"
)
print("Created name features")
# Out:
# Creating feature "artist_name_or_first_word_item_cnt_month_mean_rolling_mean_win_24"
# Creating feature "artist_name_or_first_word_city_code_item_cnt_month_mean_expanding_mean"
# Creating feature "artist_name_or_first_word_new_item_item_cnt_month_mean_expanding_mean"
# Creating feature "artist_name_or_first_word_item_cnt_month_sum_expanding_mean"
# Creating feature "artist_name_or_first_word_item_revenue_month_sum_expanding_mean"
# Created name features

# %% [markdown]
# ## Item name length as a feature
# Surprisingly predictive!

# %%
import re
def clean_item_name(string):
    # Removes bracketed terms, special characters and extra whitespace
    string = re.sub(r"\[.*?\]", "", string)
    string = re.sub(r"\(.*?\)", "", string)
    string = re.sub(r"[^A-ZА-Яa-zа-я0-9 ]", "", string)
    string = re.sub(r"\s{2,}", " ", string)
    string = string.lower()
    return string

items["item_name_cleaned_length"] = items["item_name"].apply(clean_item_name).apply(len)
items['item_name_length'] = items.item_name.apply(len)
matrix = matrix.merge(items[['item_id', 'item_name_length', 'item_name_cleaned_length']], how='left', on='item_id')

# %%
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)

# %% [markdown]
# ## Minor data leak features
# i.e. counts of new and unique items in the current month
# This counts the number of unique and new items sold in the current month and also category, which could have a positive relationship to sales. As this can also be calculated for the test set (assuming that the set of test items is the set of items that were sold in the test month) this is a kind of data leak.

# %%
def add_unique_item_features(matrix):
    # Adds the number of unique and new items per month and month-category, and these values as a proportion
    unique_id_features = (
        matrix.groupby(["date_block_num", "item_category_id"])
        .item_id.nunique()
        .rename("unique_items_cat")
        .reset_index()
    )
    unique_id = (
        unique_id_features.groupby("date_block_num").unique_items_cat.sum().rename("unique_items_month")
    )
    unique_id_features = unique_id_features.merge(
        unique_id, how="left", left_on="date_block_num", right_index=True,
    )
    unique_id_features["cat_items_proportion"] = unique_id_features["unique_items_cat"].div(
        unique_id_features["unique_items_month"]
    )
    new_items_cat = (
        matrix.loc[matrix.new_item == 1, ["date_block_num", "item_id", "item_category_id"]]
        .groupby(["date_block_num", "item_category_id"])
        .item_id.nunique()
        .rename("new_items_cat")
    )
    unique_id_features = unique_id_features.merge(
        new_items_cat, left_on=["date_block_num", "item_category_id"], right_index=True, how="left",
    )
    unique_id_features["new_items_cat"] = unique_id_features["new_items_cat"].fillna(0)
    new_items_month = (
        unique_id_features.groupby("date_block_num").new_items_cat.sum().rename("new_items_month")
    )
    unique_id_features = unique_id_features.merge(
        new_items_month, left_on="date_block_num", right_index=True, how="left"
    )
    unique_id_features["cat_items_new_proportion"] = (
        unique_id_features["new_items_cat"] / unique_id_features["unique_items_cat"]
    )
    matrix = matrix.merge(unique_id_features, on=["date_block_num", "item_category_id"], how="left")
    return matrix


matrix = add_unique_item_features(matrix)

# %%
gc.collect()
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)
# matrix.to_pickle("matrixcheckpoint_3.pk1")
print("Saved matrixcheckpoint 3")
# Out:
# Saved matrixcheckpoint 3

# %% [markdown]
# Sales of item with item_id one above or below (these tend to be related items)

# %%
def add_neighbor_item_features(matrix, feature, group= ['item_id']):
    # Item_id minus 1
    f = matrix.groupby(["date_block_num"] + group)[feature].agg("mean")
    name_minus = "minus1_" + feature
    f.name = name_minus
    f = f.reset_index(["date_block_num"] + group)
    f["item_id"] = f["item_id"] + 1
    f['date_block_num'] += 1
    matrix = matrix.merge(f, on=["date_block_num"] + group, how='left')
    matrix[name_minus] = matrix[name_minus].fillna(99)
    # Item_id plus 1
    name_plus = "plus1_" + feature
    f = f.rename(columns={name_minus:name_plus})
    f["item_id"] = f["item_id"] - 2
    f['date_block_num']
    matrix = matrix.merge(f, on=["date_block_num"] + group, how='left')
    matrix[name_plus] = matrix[name_plus].fillna(99)
    return matrix

# %%
features = ["item_id_item_cnt_day_avg_lag_1", "shop_id_item_id_item_cnt_month_sum_expanding_sum", 'item_id_item_cnt_month_sum_expanding_sum', 'item_id_item_cnt_month_mean_rolling_mean_win_12']
for feature in features:
    matrix = add_neighbor_item_features(matrix, feature)

# %%
gc.collect()
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)
matrix.to_pickle("matrixcheckpoint_4.pk1")
print("Saved matrixcheckpoint 4")
# Out:
# Saved matrixcheckpoint 4

# %% [markdown]
# Item name length as a feature.

# %% [markdown]
# ## Similar item name values

# %% [markdown]
# (mention new items) this uses the fuzzy string matching package FuzzyWuzzy to find items with similar names and return sales count values for these items in their first month of availability, weighted by their similarity to the target name. Bracketed terms are stripped from the item names before matching, because these tend to contain product codes or format information (e.g. DVD, Xbox).

# %%
items.loc[[23, 34, 12],:]
# Out:
#                               item_name  item_id  item_category_id  \
# 23                    /СЕВЕР И ЮГ /Ч.2/       23                40
# 34  10 000 ЛЕТ ДО НАШЕЙ ЭРЫ WB (регион)       34                40
# 12      *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12                55
#
#     artist_name_or_first_word  item_name_cleaned_length  item_name_length
# 23                         22                        13                17
# 34                         28                        27                35
# 12                         11                        29                31

# %%
def item_name_similarity_frame(itemsdf):
    # Makes a dataframe of similarity values between item names calculated with FuzzyWuzzy
    # itemsdf must have a supercategory_id field
    import re
    from itertools import combinations

    import scipy.sparse as sp
    from fuzzywuzzy import fuzz

    def strip_sq_brackets(string):
        return re.sub(r"\[.*?\]", "", string)

    def strip_rd_brackets(string):
        return re.sub(r"\(.*?\)", "", string)

    items["item_name"] = items["item_name"].apply(strip_sq_brackets).apply(strip_rd_brackets)

    itnames = items.item_name.to_list()
    itsupcats = items.supercategory_id.to_list()
    pairs = combinations(items.index, 2)
    sims = sp.dok_matrix((len(itnames), len(itnames)), dtype=np.int8)

    for id1, id2 in tqdm(
        pairs, total=len(itnames) * (len(itnames) - 1) / 2, desc="Calculating similarity values"
    ):
        if itsupcats[id1] != itsupcats[id2]:
            pass
        else:
            sims[id1, id2] = fuzz.token_sort_ratio(itnames[id1], itnames[id2], force_ascii=False)

    csims = sims.tocsr()
    csims = csims + csims.T
    csims = pd.DataFrame.sparse.from_spmatrix(csims)
    return csims


def make_sim_item_features(matrix, sim_frame, return_fields, sim_thresh=50, max_n=5, max_item_age=12):
    storelist = []
    mean_fields = [s + "_all_shops" for s in return_fields]
    for date_block_num in tqdm(range(3, 35), "Generating similar item name features"):
        for item_age in np.sort(matrix.loc[matrix.date_block_num == date_block_num, "item_age"].unique()):

            def get_sim_item_features(item_ids):
                slist = []
                for item_id in item_ids:
                    sim_items = sim_frame.loc[item_id, item_ids_past].nlargest(max_n)
                    sim_items = sim_items[sim_items>sim_thresh]
                    if len(sim_items)==0:
                        pass
                    else:
                        sim_item_values = (
                            past_months.loc[(slice(None), sim_items.index), return_fields]
                            .groupby("shop_id")[return_fields]
                            .mean()
                        )
                        sim_item_values[mean_fields] = sim_item_values.mean()
                        sim_item_values["item_id"] = item_id
                        slist.append(sim_item_values)
                sframe = pd.concat(slist)
                sframe["date_block_num"] = date_block_num
                sframe = sframe.reset_index()
                return sframe
            if item_age < date_block_num:
                if item_age >= max_item_age:
                    past_months = (
                        matrix.query(f"date_block_num<{date_block_num} & date_block_num>1 & item_age>={item_age}")
                        .groupby(["shop_id", "item_id"])[return_fields]
                        .mean()
                    )
                    item_ids_past = past_months.index.get_level_values("item_id").unique()
                    item_ids = matrix.query(
                        f"date_block_num=={date_block_num} & item_age>={item_age}"
                    ).item_id.unique()
                    sframe_new = get_sim_item_features(item_ids)
                    storelist = storelist + [sframe_new]
                    break
                else:
                    past_months = (
                        matrix.query(f"date_block_num<{date_block_num} & date_block_num>1 & item_age=={item_age}")
                        .groupby(["shop_id", "item_id"])[return_fields]
                        .mean()
                    )
                    item_ids_past = past_months.index.get_level_values("item_id").unique()
                    item_ids = matrix.query(
                        f"date_block_num=={date_block_num} & item_age=={item_age}"
                    ).item_id.unique()
                    sframe_new = get_sim_item_features(item_ids)
                    storelist = storelist + [sframe_new]
    sim_item_features = pd.concat(storelist)
    sim_item_field_names = {s: "sim_item_name_" + s for s in return_fields + mean_fields}
    sim_item_features = sim_item_features.rename(columns=sim_item_field_names)
    return sim_item_features


def add_sim_item_features(matrix, sim_item_features, fill_na_val=None):
    oldcols = matrix.columns
    matrix = matrix.merge(sim_item_features, on=["date_block_num", "shop_id", "item_id"], how="left")
    newcols = matrix.columns.difference(oldcols)
    if fill_na_val is not None:
        matrix[newcols] = matrix[newcols].fillna(fill_na_val)
    return matrix

# %% [markdown]
# Add the similar item name sales features. Creating these takes ~10 hours on an i7 laptop, so previously created features can be loaded instead.

# %%
load_data = "all"  # "sim_matrix" to load the name similarity matrix then compute new features, and "all" to load the features.
if load_data not in ["all", "sim_matrix"]:
    items = pd.read_csv("../input/competitive-data-science-predict-future-sales/items.csv")
    items = items.merge(
        item_categories_extra[["item_category_id", "supercategory_id"]], on="item_category_id", how="left"
    )
    sim_matrix = item_name_similarity_frame(items)
elif load_data == "sim_matrix":
    sim_matrix = pd.read_pickle("../input/predict-future-sales-extra/sim_frame_no_brackets.pk1")
    sim_item_features = make_sim_item_features(matrix, sim_matrix, ["item_cnt_month", "item_cnt_day_avg"], sim_thresh=70, max_n=5)
    sim_item_features.to_csv("sim_item_features_w_missing.csv.gz")
elif load_data == "all":
    sim_item_features = pd.read_csv("../input/predict-future-sales-extra/sim_item_features_w_missing.csv")

matrix = add_sim_item_features(matrix, sim_item_features)

# %%
missingmask = matrix["sim_item_name_item_cnt_month"].isna()
matrix.loc[missingmask, "sim_item_name_item_cnt_month"] = matrix.loc[
    missingmask, "shop_id_item_category_id_item_cnt_month_mean_expanding_mean"
]
missingmask = matrix["sim_item_name_item_cnt_month_all_shops"].isna()
matrix.loc[missingmask, "sim_item_name_item_cnt_month_all_shops"] = matrix.loc[
    missingmask, "item_category_id_item_cnt_month_mean_expanding_mean"
]
del(sim_item_features)
gc.collect()
# Out:
# 137

# %% [markdown]
# Use the mean for the supercategory / age combination to fill in missing similar name sales values for cases when no similar names were found, additionally leave the supercategory / age mean as a new feature.

# %%
matrix, oldcols = fu.shrink_mem_new_cols(matrix, oldcols)
matrix.to_pickle("matrixcheckpoint_5_nodupes.pk1")

# %%
# %reset -f

# %% [markdown]
# # Model fitting section

# %%
import gc
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm

import lightgbm as lgbm

# %%
import pandas as pd

# %%
matrix = pd.read_pickle("matrixcheckpoint_5.pk1")

# %% [markdown]
# ## Split train, validation, test sets from feature matrix

# %%
def train_test_x_y(
    matrix, test_month, keep_from_month=3, new_target=None
):
    if new_target is not None:
        matrix["item_cnt_month"] = matrix.loc[:, new_target]
        matrix = matrix.drop(columns=new_target)

    def split_train_test(matrix, test_month=33):
        # Split the matrix into train and test sets.
        test = matrix.loc[matrix.date_block_num==test_month, :]
        train = matrix.loc[matrix.date_block_num < test_month, :]
        return train, test

    def xysplit(matrix):
        # Split a train and test set into into x and y sets, with item_cnt as the target y variable
        y = matrix.item_cnt_month
        X = matrix.drop(columns=["item_cnt_month"])
        return (X, y)

    matrix = matrix.drop(
        columns=[
            "item_revenue_month",
            "item_price",
            "item_cnt_month_original",
            "item_cnt_month_unclipped",
            "item_cnt_day_avg",
            "new_item",
            "new_shop",
            "item_age",
            "shop_age",
            "digital",
            "first_item_date",
        ],
        errors="ignore",
    )

    train, test = split_train_test(matrix, test_month)
    train = train[train.date_block_num >= keep_from_month]
    X_train, y_train = xysplit(train)
    X_test, y_test = xysplit(test)
    return (X_train, y_train, X_test, y_test)

# %%
def censor_lag_features(matrix, candidate_features, replacement_val = 9999):
    # replace any lag features which are invalid due to the shop / item age being less than the lag
    def item_lag_feats(lag):
        return [
            f
            for f in candidate_features
            if f"lag_{lag}" in f
            and "item" in f
            and f[:4] != "shop"
            and "category" not in f
            and "city" not in f
            and "minus" not in f
            and "plus" not in f
            and "sim" not in f
        ]

    def shop_lag_feats(lag):
        return [
            f
            for f in candidate_features
            if f"lag_{lag}" in f
            and "shop" in f
            and "category" not in f
            and "city" not in f
            and "minus" not in f
            and "plus" not in f
            and "sim" not in f
        ]

    lags = range(1,13)
    for lag in lags:
        lag_feats = shop_lag_feats(lag)
        matrix.loc[matrix.shop_age < lag, lag_feats] = replacement_val
        lag_feats = item_lag_feats(lag)
        matrix.loc[matrix.item_age < lag, lag_feats] = replacement_val
    return matrix

# %%
import warnings

import numpy as np
import optuna
from sklearn.metrics import mean_squared_error

warnings.filterwarnings("ignore", module="lightgbm")

import lightgbm as lgbm

def fit_booster(matrix, params=None, test_run = False, categoricals=[], dropcols=[]):
    # Regular booster fitting function
    if params is None:
        params = {
            "boosting_type": "gbdt",
            "device_type": "cpu",
            "n_jobs": 11,
            "learning_rate": 0.1,
            "n_estimators": 2000,
        }

    matrix = censor_lag_features(matrix, matrix.columns, replacement_val=9999)

    if test_run:
        test_month = 34
        early_stopping_rounds=None
    else:
        test_month = 33
        early_stopping_rounds=int(1/params['learning_rate'])
    
    X_train, y_train, X_test, y_test = train_test_x_y(
        matrix.drop(columns=dropcols), test_month=test_month, keep_from_month=2,
    )

    if test_run:
        eval_set=[(X_train, y_train)]
    else:
        eval_set=[(X_train, y_train), (X_test, y_test)]

    booster = lgbm.LGBMRegressor(**params)

    booster.fit(
        X_train,
        y_train,
        eval_set=eval_set,
        eval_metric=["rmse"],
        verbose=10,
        categorical_feature=categoricals,
        early_stopping_rounds=early_stopping_rounds
    )

    if test_run:
        X_test['item_cnt_month'] = booster.predict(X_test)
        return booster, X_test
    else:
        return booster

# %%
import optuna
from sklearn.metrics import mean_squared_error

import lightgbm as lgbm

class Objective(object):
    def __init__(self, matrix):
        matrix = censor_lag_features(matrix, matrix.columns, replacement_val=9999)
        self.X_train, self.y_train, self.X_valid, self.y_valid = train_test_x_y(
            matrix, test_month=33, keep_from_month=2,
            )

    def __call__(self, trial):
        params = {
            "boosting_type": "gbdt",
            "device_type": "cpu",
            "n_jobs": 11,
            "silent": True,
            "n_estimators": 1000,
            "learning_rate": 0.1,
            "bagging_seed": 3,
            "subsample_for_bin": 300000,
            "max_depth": -1,
            "min_data_in_bin": 1,
            "num_leaves": trial.suggest_int("num_leaves", 255, 2048, log=True),
            "cat_smooth": trial.suggest_float("cat_smooth", 10, 100, log=True),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.3, 1.0),
            "min_child_samples": trial.suggest_int("min_child_samples", 1, 10),
            "min_child_weight": trial.suggest_float("min_child_weight", 0.001, 2, log=True),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "subsample_freq": trial.suggest_int("subsample_freq", 1, 8),
            "max_bin": trial.suggest_int("max_bin", 16, 255, log=True),
        }

        categoricals = [
            "item_category_id",
            "month",
            'artist_name_or_first_word',
        ]
        
        if trial.suggest_categorical("interaction_month_digital_categorical", [True, False]):
            categoricals = categoricals + ["interaction_month_digital"]
        if trial.suggest_categorical("interaction_month_item_category_id_categorical", [True, False]):
            categoricals = categoricals + ["interaction_month_item_category_id"]
        
        categoricals = [c for c in categoricals if c in self.X_train.columns]
        
        early_stopping_rounds=int(1/params['learning_rate'])
        
        # Add a callback for pruning.
        pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "rmse")

        booster = lgbm.LGBMRegressor(**params)

        booster.fit(
            self.X_train,
            self.y_train,
            eval_set=[(self.X_valid, self.y_valid)],
            eval_metric=["rmse"],
            callbacks=[pruning_callback],
            verbose=False,
            categorical_feature=categoricals,
            early_stopping_rounds=early_stopping_rounds
            
        )

        predictions = booster.predict(self.X_valid)
        rmse = mean_squared_error(self.y_valid, predictions.clip(0,20), squared=False)

        return rmse


import warnings

# warnings.filterwarnings("ignore", message="", module="lightgbm", lineno=1286)
warnings.filterwarnings("ignore", message="", module="lightgbm")

study = optuna.create_study(pruner=optuna.pruners.MedianPruner(n_warmup_steps=15), direction="minimize")
study.optimize(Objective(matrix), n_trials=200, gc_after_trial=True)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2021-03-26 10:15:28,727] A new study created in memory with name: no-name-23beb910-6b95-4b95-a5b9-e0eb20674410
# [I 2021-03-26 10:19:30,056] Trial 0 finished with value: 0.7720416590768797 and parameters: {'num_leaves': 1353, 'cat_smooth': 19.530517651986283, 'colsample_bytree': 0.362724594769234, 'min_child_samples': 3, 'min_child_weight': 0.8845902725153495, 'subsample': 0.822119763079142, 'subsample_freq': 7, 'max_bin': 200, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 0 with value: 0.7720416590768797.
# [I 2021-03-26 10:21:37,970] Trial 1 finished with value: 0.7713847514771989 and parameters: {'num_leaves': 506, 'cat_smooth': 84.3846270815777, 'colsample_bytree': 0.7519090918532384, 'min_child_samples': 7, 'min_child_weight': 0.02563315416326339, 'subsample': 0.8616269267308441, 'subsample_freq': 1, 'max_bin': 45, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 1 with value: 0.7713847514771989.
# [I 2021-03-26 10:23:39,459] Trial 2 finished with value: 0.774680270464956 and parameters: {'num_leaves': 1367, 'cat_smooth': 22.21450667945537, 'colsample_bytree': 0.48737126172756107, 'min_child_samples': 8, 'min_child_weight': 0.02242630849642571, 'subsample': 0.7934665063536663, 'subsample_freq': 3, 'max_bin': 84, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 1 with value: 0.7713847514771989.
# [I 2021-03-26 10:25:23,860] Trial 3 finished with value: 0.7747991719885341 and parameters: {'num_leaves': 724, 'cat_smooth': 28.57731223865273, 'colsample_bytree': 0.3894862223978788, 'min_child_samples': 2, 'min_child_weight': 0.1444922005878336, 'subsample': 0.7747315388124189, 'subsample_freq': 6, 'max_bin': 23, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': False}. Best is trial 1 with value: 0.7713847514771989.
# [I 2021-03-26 10:27:09,098] Trial 4 finished with value: 0.774665493637681 and parameters: {'num_leaves': 582, 'cat_smooth': 14.605534220786028, 'colsample_bytree': 0.6016122525369069, 'min_child_samples': 7, 'min_child_weight': 0.291559172381182, 'subsample': 0.5997264662617566, 'subsample_freq': 4, 'max_bin': 50, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 1 with value: 0.7713847514771989.
# [I 2021-03-26 10:28:06,365] Trial 5 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:30:03,984] Trial 6 finished with value: 0.7649609027790455 and parameters: {'num_leaves': 329, 'cat_smooth': 62.410108049586576, 'colsample_bytree': 0.8694245865035897, 'min_child_samples': 7, 'min_child_weight': 0.01703663669160774, 'subsample': 0.7101836103382091, 'subsample_freq': 7, 'max_bin': 134, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 6 with value: 0.7649609027790455.
# [I 2021-03-26 10:30:56,793] Trial 7 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:32:23,700] Trial 8 pruned. Trial was pruned at iteration 25.
# [I 2021-03-26 10:35:15,829] Trial 9 finished with value: 0.7612899962929713 and parameters: {'num_leaves': 605, 'cat_smooth': 15.003810890692609, 'colsample_bytree': 0.7640578452052023, 'min_child_samples': 3, 'min_child_weight': 0.07752888240165114, 'subsample': 0.7103104012864104, 'subsample_freq': 2, 'max_bin': 79, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': False}. Best is trial 9 with value: 0.7612899962929713.
# [I 2021-03-26 10:36:08,086] Trial 10 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:38:06,904] Trial 11 finished with value: 0.7658805684336014 and parameters: {'num_leaves': 293, 'cat_smooth': 54.90315842923011, 'colsample_bytree': 0.9703501028498847, 'min_child_samples': 10, 'min_child_weight': 0.007182961525857332, 'subsample': 0.6941467514951937, 'subsample_freq': 5, 'max_bin': 123, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': False}. Best is trial 9 with value: 0.7612899962929713.
# [I 2021-03-26 10:39:58,769] Trial 12 finished with value: 0.7619048491227107 and parameters: {'num_leaves': 360, 'cat_smooth': 46.34994896351245, 'colsample_bytree': 0.87225197880919, 'min_child_samples': 4, 'min_child_weight': 0.06184358362090808, 'subsample': 0.6874152032554347, 'subsample_freq': 8, 'max_bin': 250, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 9 with value: 0.7612899962929713.
# [I 2021-03-26 10:40:53,017] Trial 13 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:42:52,295] Trial 14 finished with value: 0.757538297583649 and parameters: {'num_leaves': 923, 'cat_smooth': 40.36614794326289, 'colsample_bytree': 0.6966928229769541, 'min_child_samples': 1, 'min_child_weight': 0.06499762672295722, 'subsample': 0.630528513939256, 'subsample_freq': 4, 'max_bin': 33, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 14 with value: 0.757538297583649.
# [I 2021-03-26 10:43:51,477] Trial 15 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:44:59,596] Trial 16 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:45:59,747] Trial 17 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:47:50,607] Trial 18 pruned. Trial was pruned at iteration 31.
# [I 2021-03-26 10:48:43,213] Trial 19 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:50:17,368] Trial 20 pruned. Trial was pruned at iteration 20.
# [I 2021-03-26 10:51:21,507] Trial 21 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:52:16,923] Trial 22 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:54:45,649] Trial 23 finished with value: 0.7631247493568477 and parameters: {'num_leaves': 616, 'cat_smooth': 46.42852992754685, 'colsample_bytree': 0.7261098347219244, 'min_child_samples': 4, 'min_child_weight': 0.04237411365515544, 'subsample': 0.7413350178598372, 'subsample_freq': 3, 'max_bin': 248, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 14 with value: 0.757538297583649.
# [I 2021-03-26 10:56:00,680] Trial 24 pruned. Trial was pruned at iteration 17.
# [I 2021-03-26 10:56:51,761] Trial 25 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 10:59:20,267] Trial 26 finished with value: 0.7592111457644739 and parameters: {'num_leaves': 743, 'cat_smooth': 38.784889442403475, 'colsample_bytree': 0.6891716699720928, 'min_child_samples': 5, 'min_child_weight': 0.015341294442629619, 'subsample': 0.7467713199981679, 'subsample_freq': 2, 'max_bin': 86, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 14 with value: 0.757538297583649.
# [I 2021-03-26 11:00:19,473] Trial 27 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:01:17,385] Trial 28 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:03:34,972] Trial 29 finished with value: 0.7586147390055274 and parameters: {'num_leaves': 1258, 'cat_smooth': 98.06243097325847, 'colsample_bytree': 0.6191258915963739, 'min_child_samples': 6, 'min_child_weight': 0.02998682224920915, 'subsample': 0.8388429888155048, 'subsample_freq': 1, 'max_bin': 60, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 14 with value: 0.757538297583649.
# [I 2021-03-26 11:04:38,826] Trial 30 pruned. Trial was pruned at iteration 16.
# [I 2021-03-26 11:05:37,791] Trial 31 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:06:39,065] Trial 32 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:07:40,980] Trial 33 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:09:46,962] Trial 34 pruned. Trial was pruned at iteration 58.
# [I 2021-03-26 11:10:43,078] Trial 35 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:11:37,073] Trial 36 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:12:51,710] Trial 37 pruned. Trial was pruned at iteration 33.
# [I 2021-03-26 11:15:15,034] Trial 38 finished with value: 0.7565543108567948 and parameters: {'num_leaves': 803, 'cat_smooth': 54.21867149155019, 'colsample_bytree': 0.4419848255797345, 'min_child_samples': 7, 'min_child_weight': 0.0054969296085684155, 'subsample': 0.6455223131545287, 'subsample_freq': 1, 'max_bin': 57, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': False}. Best is trial 38 with value: 0.7565543108567948.
# [I 2021-03-26 11:15:51,593] Trial 39 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:16:44,094] Trial 40 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:17:20,248] Trial 41 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:18:05,167] Trial 42 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:19:11,066] Trial 43 pruned. Trial was pruned at iteration 26.
# [I 2021-03-26 11:20:03,292] Trial 44 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:20:55,189] Trial 45 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:22:02,350] Trial 46 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:23:09,796] Trial 47 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:24:18,463] Trial 48 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:25:05,704] Trial 49 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:25:59,616] Trial 50 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:28:04,289] Trial 51 finished with value: 0.7582889588723943 and parameters: {'num_leaves': 307, 'cat_smooth': 48.48459902147499, 'colsample_bytree': 0.8750193686098934, 'min_child_samples': 4, 'min_child_weight': 0.06440691970310641, 'subsample': 0.6723774391969574, 'subsample_freq': 8, 'max_bin': 217, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 38 with value: 0.7565543108567948.
# [I 2021-03-26 11:28:52,031] Trial 52 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:29:48,624] Trial 53 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:32:28,310] Trial 54 finished with value: 0.7613462587828314 and parameters: {'num_leaves': 1376, 'cat_smooth': 59.33915786848949, 'colsample_bytree': 0.7930234855591006, 'min_child_samples': 5, 'min_child_weight': 0.04976286295562877, 'subsample': 0.6875996028300818, 'subsample_freq': 1, 'max_bin': 90, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 38 with value: 0.7565543108567948.
# [I 2021-03-26 11:33:37,104] Trial 55 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:34:33,896] Trial 56 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:35:36,968] Trial 57 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:36:17,924] Trial 58 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:37:33,536] Trial 59 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:38:33,624] Trial 60 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:39:51,578] Trial 61 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:43:02,383] Trial 62 finished with value: 0.7617741135810541 and parameters: {'num_leaves': 1829, 'cat_smooth': 56.90716608280542, 'colsample_bytree': 0.7833655144716349, 'min_child_samples': 5, 'min_child_weight': 0.06618315616589725, 'subsample': 0.6908407764296883, 'subsample_freq': 2, 'max_bin': 113, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 38 with value: 0.7565543108567948.
# [I 2021-03-26 11:45:24,692] Trial 63 finished with value: 0.7636405059751881 and parameters: {'num_leaves': 1419, 'cat_smooth': 64.56261626974882, 'colsample_bytree': 0.7523773166789949, 'min_child_samples': 3, 'min_child_weight': 0.045739233620398514, 'subsample': 0.6155652363098965, 'subsample_freq': 1, 'max_bin': 89, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 38 with value: 0.7565543108567948.
# [I 2021-03-26 11:46:37,497] Trial 64 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:48:54,731] Trial 65 finished with value: 0.757360040865801 and parameters: {'num_leaves': 1209, 'cat_smooth': 75.02225257921279, 'colsample_bytree': 0.663844911792201, 'min_child_samples': 4, 'min_child_weight': 0.0011120415133665529, 'subsample': 0.6460564970517885, 'subsample_freq': 7, 'max_bin': 63, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 38 with value: 0.7565543108567948.
# [I 2021-03-26 11:50:04,337] Trial 66 pruned. Trial was pruned at iteration 20.
# [I 2021-03-26 11:51:06,947] Trial 67 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 11:53:39,898] Trial 68 finished with value: 0.7528933390520579 and parameters: {'num_leaves': 834, 'cat_smooth': 75.64625031180228, 'colsample_bytree': 0.6697656780739069, 'min_child_samples': 4, 'min_child_weight': 0.07616658847661764, 'subsample': 0.650196876768557, 'subsample_freq': 7, 'max_bin': 47, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 11:55:11,286] Trial 69 pruned. Trial was pruned at iteration 39.
# [I 2021-03-26 11:56:28,848] Trial 70 pruned. Trial was pruned at iteration 27.
# [I 2021-03-26 11:58:46,430] Trial 71 finished with value: 0.7598733069544369 and parameters: {'num_leaves': 1189, 'cat_smooth': 71.78273706210686, 'colsample_bytree': 0.7128548327741789, 'min_child_samples': 4, 'min_child_weight': 0.07177537519394275, 'subsample': 0.6377966222260413, 'subsample_freq': 8, 'max_bin': 46, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:00:54,816] Trial 72 finished with value: 0.7621903798738868 and parameters: {'num_leaves': 1181, 'cat_smooth': 73.59988830258533, 'colsample_bytree': 0.7103741489400497, 'min_child_samples': 4, 'min_child_weight': 0.0010124299243107926, 'subsample': 0.5681400359244566, 'subsample_freq': 8, 'max_bin': 45, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:01:53,947] Trial 73 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:02:50,983] Trial 74 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:04:33,519] Trial 75 finished with value: 0.7606277868273181 and parameters: {'num_leaves': 889, 'cat_smooth': 44.11058388020266, 'colsample_bytree': 0.6294515335284422, 'min_child_samples': 4, 'min_child_weight': 0.20789334181743474, 'subsample': 0.6006713797819041, 'subsample_freq': 7, 'max_bin': 47, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:05:25,959] Trial 76 pruned. Trial was pruned at iteration 18.
# [I 2021-03-26 12:07:56,269] Trial 77 finished with value: 0.7535289970579981 and parameters: {'num_leaves': 1592, 'cat_smooth': 50.728543180420495, 'colsample_bytree': 0.7382262401839642, 'min_child_samples': 5, 'min_child_weight': 0.08131429164301632, 'subsample': 0.6620083591584538, 'subsample_freq': 8, 'max_bin': 43, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:09:00,334] Trial 78 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:11:00,349] Trial 79 finished with value: 0.7545434708490133 and parameters: {'num_leaves': 1644, 'cat_smooth': 64.52173353771417, 'colsample_bytree': 0.5580532723196187, 'min_child_samples': 7, 'min_child_weight': 0.058566571393324066, 'subsample': 0.5366274460024553, 'subsample_freq': 7, 'max_bin': 52, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:11:59,663] Trial 80 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:14:33,311] Trial 81 finished with value: 0.7535054679958166 and parameters: {'num_leaves': 1649, 'cat_smooth': 55.53441592853565, 'colsample_bytree': 0.6137614859233353, 'min_child_samples': 7, 'min_child_weight': 0.040672841848693804, 'subsample': 0.5165205842937921, 'subsample_freq': 7, 'max_bin': 52, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:15:49,053] Trial 82 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:16:49,484] Trial 83 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:17:49,179] Trial 84 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:19:07,876] Trial 85 pruned. Trial was pruned at iteration 20.
# [I 2021-03-26 12:20:10,240] Trial 86 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:21:13,212] Trial 87 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:22:03,106] Trial 88 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:24:21,454] Trial 89 finished with value: 0.7575284174525876 and parameters: {'num_leaves': 1584, 'cat_smooth': 49.5987035871789, 'colsample_bytree': 0.5583970697150776, 'min_child_samples': 7, 'min_child_weight': 0.10263707472791084, 'subsample': 0.6636520694977578, 'subsample_freq': 7, 'max_bin': 65, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:25:16,027] Trial 90 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:26:19,560] Trial 91 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:27:31,224] Trial 92 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:28:34,864] Trial 93 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:29:59,162] Trial 94 pruned. Trial was pruned at iteration 20.
# [I 2021-03-26 12:32:35,509] Trial 95 finished with value: 0.7574707381256474 and parameters: {'num_leaves': 1507, 'cat_smooth': 59.3620993327551, 'colsample_bytree': 0.6768683307432588, 'min_child_samples': 8, 'min_child_weight': 0.05394462528828082, 'subsample': 0.6848595569640173, 'subsample_freq': 7, 'max_bin': 70, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:33:43,824] Trial 96 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:36:05,041] Trial 97 finished with value: 0.7586583344263664 and parameters: {'num_leaves': 1387, 'cat_smooth': 66.02007369846964, 'colsample_bytree': 0.6925229413842076, 'min_child_samples': 8, 'min_child_weight': 0.07234605758050887, 'subsample': 0.6562185504224084, 'subsample_freq': 7, 'max_bin': 64, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:37:04,475] Trial 98 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:38:01,905] Trial 99 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:39:05,957] Trial 100 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:40:08,241] Trial 101 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:41:10,118] Trial 102 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:42:26,890] Trial 103 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:44:28,885] Trial 104 pruned. Trial was pruned at iteration 38.
# [I 2021-03-26 12:45:16,924] Trial 105 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:46:11,611] Trial 106 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:47:07,217] Trial 107 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:48:13,332] Trial 108 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:49:29,543] Trial 109 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:50:21,028] Trial 110 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:51:51,553] Trial 111 pruned. Trial was pruned at iteration 27.
# [I 2021-03-26 12:53:18,255] Trial 112 pruned. Trial was pruned at iteration 28.
# [I 2021-03-26 12:54:24,619] Trial 113 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:56:18,850] Trial 114 finished with value: 0.759550289759209 and parameters: {'num_leaves': 1100, 'cat_smooth': 54.60071804604582, 'colsample_bytree': 0.6822697782591076, 'min_child_samples': 7, 'min_child_weight': 0.13043133422513656, 'subsample': 0.6925149630002378, 'subsample_freq': 7, 'max_bin': 56, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 12:57:25,216] Trial 115 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:58:16,186] Trial 116 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 12:59:13,074] Trial 117 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:00:07,261] Trial 118 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:01:06,156] Trial 119 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:02:16,490] Trial 120 pruned. Trial was pruned at iteration 19.
# [I 2021-03-26 13:03:12,387] Trial 121 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:04:10,913] Trial 122 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:07:11,349] Trial 123 finished with value: 0.7542696830570649 and parameters: {'num_leaves': 1481, 'cat_smooth': 35.27844004198552, 'colsample_bytree': 0.6910548773703133, 'min_child_samples': 6, 'min_child_weight': 0.01235712116474021, 'subsample': 0.7519152472861641, 'subsample_freq': 1, 'max_bin': 136, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 13:08:21,688] Trial 124 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:09:25,436] Trial 125 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:10:31,632] Trial 126 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:11:36,645] Trial 127 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:12:56,741] Trial 128 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:13:54,822] Trial 129 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:14:58,318] Trial 130 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:15:46,165] Trial 131 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:16:37,592] Trial 132 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:17:40,757] Trial 133 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:18:34,662] Trial 134 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:19:21,899] Trial 135 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:20:14,642] Trial 136 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:21:28,122] Trial 137 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:22:40,795] Trial 138 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:24:51,885] Trial 139 finished with value: 0.7585501568750386 and parameters: {'num_leaves': 1330, 'cat_smooth': 43.94943251609281, 'colsample_bytree': 0.6202923176858642, 'min_child_samples': 8, 'min_child_weight': 0.005965597605431909, 'subsample': 0.500088654471545, 'subsample_freq': 6, 'max_bin': 239, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 13:25:48,981] Trial 140 pruned. Trial was pruned at iteration 16.
# [I 2021-03-26 13:27:07,741] Trial 141 pruned. Trial was pruned at iteration 23.
# [I 2021-03-26 13:28:11,833] Trial 142 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:29:12,612] Trial 143 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:30:15,198] Trial 144 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:31:13,977] Trial 145 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:32:03,996] Trial 146 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:33:03,568] Trial 147 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:34:04,778] Trial 148 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:35:09,667] Trial 149 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:36:07,748] Trial 150 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:37:00,268] Trial 151 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:37:54,908] Trial 152 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:38:52,946] Trial 153 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:39:56,995] Trial 154 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:40:54,812] Trial 155 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:42:01,858] Trial 156 pruned. Trial was pruned at iteration 20.
# [I 2021-03-26 13:42:54,580] Trial 157 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:43:52,281] Trial 158 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:44:49,769] Trial 159 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:46:17,567] Trial 160 pruned. Trial was pruned at iteration 19.
# [I 2021-03-26 13:48:35,458] Trial 161 finished with value: 0.7593784963783862 and parameters: {'num_leaves': 1104, 'cat_smooth': 72.34227795536097, 'colsample_bytree': 0.7063343558291743, 'min_child_samples': 4, 'min_child_weight': 0.06981419023546423, 'subsample': 0.6744552184557732, 'subsample_freq': 8, 'max_bin': 45, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 13:51:43,442] Trial 162 finished with value: 0.7569870957318554 and parameters: {'num_leaves': 1060, 'cat_smooth': 85.04387935532824, 'colsample_bytree': 0.7112234445024893, 'min_child_samples': 4, 'min_child_weight': 0.06653814400928541, 'subsample': 0.6764788547112984, 'subsample_freq': 8, 'max_bin': 51, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 13:52:47,400] Trial 163 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:55:10,098] Trial 164 finished with value: 0.757384357268248 and parameters: {'num_leaves': 1060, 'cat_smooth': 80.3708645858997, 'colsample_bytree': 0.7259702014456322, 'min_child_samples': 4, 'min_child_weight': 0.05485216443071201, 'subsample': 0.6591921839404956, 'subsample_freq': 8, 'max_bin': 47, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 13:56:10,990] Trial 165 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:57:14,355] Trial 166 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 13:58:31,633] Trial 167 pruned. Trial was pruned at iteration 17.
# [I 2021-03-26 14:01:54,740] Trial 168 finished with value: 0.7569626867325223 and parameters: {'num_leaves': 1785, 'cat_smooth': 94.9668657148291, 'colsample_bytree': 0.9476134577062483, 'min_child_samples': 5, 'min_child_weight': 0.08331839145307407, 'subsample': 0.6592710486303686, 'subsample_freq': 8, 'max_bin': 65, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 14:03:19,175] Trial 169 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:04:21,593] Trial 170 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:05:39,077] Trial 171 pruned. Trial was pruned at iteration 18.
# [I 2021-03-26 14:06:48,156] Trial 172 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:07:57,050] Trial 173 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:08:59,576] Trial 174 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:10:10,677] Trial 175 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:11:11,916] Trial 176 pruned. Trial was pruned at iteration 16.
# [I 2021-03-26 14:12:06,316] Trial 177 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:12:55,495] Trial 178 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:14:05,616] Trial 179 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:14:53,965] Trial 180 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:15:57,517] Trial 181 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:18:04,993] Trial 182 finished with value: 0.7560524168165768 and parameters: {'num_leaves': 1079, 'cat_smooth': 64.00733068270233, 'colsample_bytree': 0.6934658922791248, 'min_child_samples': 4, 'min_child_weight': 0.07375652414711507, 'subsample': 0.6700892950756586, 'subsample_freq': 8, 'max_bin': 54, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 68 with value: 0.7528933390520579.
# [I 2021-03-26 14:19:07,925] Trial 183 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:20:11,148] Trial 184 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:23:03,348] Trial 185 finished with value: 0.7470939953273252 and parameters: {'num_leaves': 1054, 'cat_smooth': 74.99994145686956, 'colsample_bytree': 0.7487432303818875, 'min_child_samples': 8, 'min_child_weight': 0.07457532728473812, 'subsample': 0.6653349943746963, 'subsample_freq': 8, 'max_bin': 47, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 185 with value: 0.7470939953273252.
# [I 2021-03-26 14:24:09,305] Trial 186 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:25:24,353] Trial 187 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:26:28,042] Trial 188 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:27:11,965] Trial 189 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:27:51,847] Trial 190 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:28:30,870] Trial 191 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:29:12,025] Trial 192 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:29:47,348] Trial 193 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:31:38,372] Trial 194 finished with value: 0.7581990243381638 and parameters: {'num_leaves': 1261, 'cat_smooth': 92.34545272976736, 'colsample_bytree': 0.771896283276943, 'min_child_samples': 8, 'min_child_weight': 0.09541452330958934, 'subsample': 0.7892183503884829, 'subsample_freq': 7, 'max_bin': 52, 'interaction_month_digital_categorical': True, 'interaction_month_item_category_id_categorical': True}. Best is trial 185 with value: 0.7470939953273252.
# [I 2021-03-26 14:32:42,592] Trial 195 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:33:46,393] Trial 196 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:35:16,737] Trial 197 finished with value: 0.7539940396458037 and parameters: {'num_leaves': 1314, 'cat_smooth': 95.43061041327756, 'colsample_bytree': 0.7416427969414953, 'min_child_samples': 8, 'min_child_weight': 0.06388868870249759, 'subsample': 0.8434158229324932, 'subsample_freq': 7, 'max_bin': 51, 'interaction_month_digital_categorical': False, 'interaction_month_item_category_id_categorical': True}. Best is trial 185 with value: 0.7470939953273252.
# [I 2021-03-26 14:35:55,731] Trial 198 pruned. Trial was pruned at iteration 15.
# [I 2021-03-26 14:37:04,320] Trial 199 pruned. Trial was pruned at iteration 37.
# Number of finished trials: 200
# Best trial:
#   Value: 0.7470939953273252
#   Params:
#     num_leaves: 1054
#     cat_smooth: 74.99994145686956
#     colsample_bytree: 0.7487432303818875
#     min_child_samples: 8
#     min_child_weight: 0.07457532728473812
#     subsample: 0.6653349943746963
#     subsample_freq: 8
#     max_bin: 47
#     interaction_month_digital_categorical: True
#     interaction_month_item_category_id_categorical: True

# %%
import joblib
from datetime import datetime
fname = f'optuna_results_{datetime.now().strftime("%Y%m%d_%H%M")}.pk1'
joblib.dump(study, fname)
# Out:
# ['optuna_results_20210326_1437.pk1']

# %%
raise ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-e4c8e09828d5> in <module>
# ----> 1 raise ValueError
#
# ValueError:

# %%
import joblib
# filename = 'optuna_results_20210325_1937.pk1'
study = joblib.load(fname)

# %%
best_params = study.best_params

for k in ["shop_id_categorical", "interaction_month_digital_categorical", "city_id_categorical", "interaction_month_item_category_id_categorical"]:
    best_params.pop(k, None)

other_params = {
    "boosting_type": "gbdt",
    "device_type": "cpu",
    "n_jobs": 11,
    "silent": True,
    "n_estimators": 10000,
    "learning_rate": 0.01,
    "bagging_seed": 3,
    "subsample_for_bin": 300000,
    "max_depth": -1,
    "min_data_in_bin": 1,
}

best_params = {**best_params, **other_params}

categoricals = [
    "item_category_id",
    "month",
    "artist_name_or_first_word",
    "interaction_month_digital",
    "interaction_month_item_category_id",
]

booster = fit_booster(matrix, params=best_params, test_run = False, categoricals=categoricals, dropcols=[])
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	training's rmse: 1.16693	training's l2: 1.36173	valid_1's rmse: 1.03189	valid_1's l2: 1.0648
# [20]	training's rmse: 1.10593	training's l2: 1.22309	valid_1's rmse: 0.991076	valid_1's l2: 0.982232
# [30]	training's rmse: 1.05251	training's l2: 1.10778	valid_1's rmse: 0.956329	valid_1's l2: 0.914565
# [40]	training's rmse: 1.00549	training's l2: 1.01102	valid_1's rmse: 0.926459	valid_1's l2: 0.858326
# [50]	training's rmse: 0.964729	training's l2: 0.930702	valid_1's rmse: 0.900485	valid_1's l2: 0.810873
# [60]	training's rmse: 0.928827	training's l2: 0.86272	valid_1's rmse: 0.8799	valid_1's l2: 0.774223
# [70]	training's rmse: 0.897006	training's l2: 0.804619	valid_1's rmse: 0.862223	valid_1's l2: 0.743429
# [80]	training's rmse: 0.869499	training's l2: 0.756029	valid_1's rmse: 0.846655	valid_1's l2: 0.716824
# [90]	training's rmse: 0.845122	training's l2: 0.71423	valid_1's rmse: 0.833243	valid_1's l2: 0.694294
# [100]	training's rmse: 0.823838	training's l2: 0.678709	valid_1's rmse: 0.822774	valid_1's l2: 0.676957
# [110]	training's rmse: 0.80532	training's l2: 0.648541	valid_1's rmse: 0.813516	valid_1's l2: 0.661809
# [120]	training's rmse: 0.788788	training's l2: 0.622187	valid_1's rmse: 0.805598	valid_1's l2: 0.648988
# [130]	training's rmse: 0.774268	training's l2: 0.599492	valid_1's rmse: 0.798979	valid_1's l2: 0.638368
# [140]	training's rmse: 0.761185	training's l2: 0.579403	valid_1's rmse: 0.793189	valid_1's l2: 0.629148
# [150]	training's rmse: 0.749685	training's l2: 0.562027	valid_1's rmse: 0.788106	valid_1's l2: 0.62111
# [160]	training's rmse: 0.739398	training's l2: 0.546709	valid_1's rmse: 0.784433	valid_1's l2: 0.615335
# [170]	training's rmse: 0.729928	training's l2: 0.532795	valid_1's rmse: 0.780938	valid_1's l2: 0.609864
# [180]	training's rmse: 0.721567	training's l2: 0.520658	valid_1's rmse: 0.777611	valid_1's l2: 0.604678
# [190]	training's rmse: 0.714065	training's l2: 0.509888	valid_1's rmse: 0.775566	valid_1's l2: 0.601503
# [200]	training's rmse: 0.707039	training's l2: 0.499905	valid_1's rmse: 0.773326	valid_1's l2: 0.598033
# [210]	training's rmse: 0.700543	training's l2: 0.49076	valid_1's rmse: 0.771427	valid_1's l2: 0.5951
# [220]	training's rmse: 0.69488	training's l2: 0.482858	valid_1's rmse: 0.769511	valid_1's l2: 0.592147
# [230]	training's rmse: 0.689685	training's l2: 0.475665	valid_1's rmse: 0.768376	valid_1's l2: 0.590401
# [240]	training's rmse: 0.684612	training's l2: 0.468693	valid_1's rmse: 0.767089	valid_1's l2: 0.588425
# [250]	training's rmse: 0.680149	training's l2: 0.462603	valid_1's rmse: 0.765945	valid_1's l2: 0.586671
# [260]	training's rmse: 0.675782	training's l2: 0.456682	valid_1's rmse: 0.764966	valid_1's l2: 0.585172
# [270]	training's rmse: 0.671608	training's l2: 0.451058	valid_1's rmse: 0.764363	valid_1's l2: 0.584251
# [280]	training's rmse: 0.667618	training's l2: 0.445713	valid_1's rmse: 0.763905	valid_1's l2: 0.583551
# [290]	training's rmse: 0.663754	training's l2: 0.440569	valid_1's rmse: 0.763135	valid_1's l2: 0.582375
# [300]	training's rmse: 0.660401	training's l2: 0.43613	valid_1's rmse: 0.762593	valid_1's l2: 0.581548
# [310]	training's rmse: 0.657249	training's l2: 0.431976	valid_1's rmse: 0.762245	valid_1's l2: 0.581017
# [320]	training's rmse: 0.654329	training's l2: 0.428146	valid_1's rmse: 0.761856	valid_1's l2: 0.580424
# [330]	training's rmse: 0.651398	training's l2: 0.424319	valid_1's rmse: 0.76105	valid_1's l2: 0.579196
# [340]	training's rmse: 0.648605	training's l2: 0.420689	valid_1's rmse: 0.760624	valid_1's l2: 0.578549
# [350]	training's rmse: 0.645831	training's l2: 0.417098	valid_1's rmse: 0.760398	valid_1's l2: 0.578205
# [360]	training's rmse: 0.643169	training's l2: 0.413666	valid_1's rmse: 0.759918	valid_1's l2: 0.577475
# [370]	training's rmse: 0.640768	training's l2: 0.410584	valid_1's rmse: 0.759756	valid_1's l2: 0.577229
# [380]	training's rmse: 0.638352	training's l2: 0.407494	valid_1's rmse: 0.759509	valid_1's l2: 0.576855
# [390]	training's rmse: 0.636099	training's l2: 0.404622	valid_1's rmse: 0.75927	valid_1's l2: 0.57649
# [400]	training's rmse: 0.633839	training's l2: 0.401752	valid_1's rmse: 0.759039	valid_1's l2: 0.57614
# [410]	training's rmse: 0.631598	training's l2: 0.398916	valid_1's rmse: 0.758844	valid_1's l2: 0.575844
# [420]	training's rmse: 0.629493	training's l2: 0.396262	valid_1's rmse: 0.758691	valid_1's l2: 0.575612
# [430]	training's rmse: 0.627455	training's l2: 0.3937	valid_1's rmse: 0.758649	valid_1's l2: 0.575548
# [440]	training's rmse: 0.625512	training's l2: 0.391265	valid_1's rmse: 0.758305	valid_1's l2: 0.575026
# [450]	training's rmse: 0.623699	training's l2: 0.389	valid_1's rmse: 0.758117	valid_1's l2: 0.574741
# [460]	training's rmse: 0.621899	training's l2: 0.386759	valid_1's rmse: 0.758095	valid_1's l2: 0.574708
# [470]	training's rmse: 0.6202	training's l2: 0.384649	valid_1's rmse: 0.757894	valid_1's l2: 0.574403
# [480]	training's rmse: 0.618502	training's l2: 0.382545	valid_1's rmse: 0.757723	valid_1's l2: 0.574143
# [490]	training's rmse: 0.616824	training's l2: 0.380472	valid_1's rmse: 0.757544	valid_1's l2: 0.573873
# [500]	training's rmse: 0.61527	training's l2: 0.378557	valid_1's rmse: 0.75758	valid_1's l2: 0.573927
# [510]	training's rmse: 0.61363	training's l2: 0.376542	valid_1's rmse: 0.75747	valid_1's l2: 0.57376
# [520]	training's rmse: 0.612071	training's l2: 0.37463	valid_1's rmse: 0.757318	valid_1's l2: 0.573531
# [530]	training's rmse: 0.610567	training's l2: 0.372792	valid_1's rmse: 0.757226	valid_1's l2: 0.573392
# [540]	training's rmse: 0.609118	training's l2: 0.371025	valid_1's rmse: 0.756913	valid_1's l2: 0.572918
# [550]	training's rmse: 0.607728	training's l2: 0.369334	valid_1's rmse: 0.756912	valid_1's l2: 0.572915
# [560]	training's rmse: 0.60633	training's l2: 0.367636	valid_1's rmse: 0.756885	valid_1's l2: 0.572875
# [570]	training's rmse: 0.604818	training's l2: 0.365804	valid_1's rmse: 0.756799	valid_1's l2: 0.572744
# [580]	training's rmse: 0.603389	training's l2: 0.364079	valid_1's rmse: 0.756879	valid_1's l2: 0.572866
# [590]	training's rmse: 0.60205	training's l2: 0.362464	valid_1's rmse: 0.756768	valid_1's l2: 0.572697
# [600]	training's rmse: 0.600688	training's l2: 0.360826	valid_1's rmse: 0.756612	valid_1's l2: 0.572462
# [610]	training's rmse: 0.599486	training's l2: 0.359383	valid_1's rmse: 0.756598	valid_1's l2: 0.57244
# [620]	training's rmse: 0.59824	training's l2: 0.357891	valid_1's rmse: 0.7566	valid_1's l2: 0.572443
# [630]	training's rmse: 0.597026	training's l2: 0.35644	valid_1's rmse: 0.756549	valid_1's l2: 0.572366
# [640]	training's rmse: 0.595814	training's l2: 0.354994	valid_1's rmse: 0.756539	valid_1's l2: 0.572351
# [650]	training's rmse: 0.594646	training's l2: 0.353604	valid_1's rmse: 0.756501	valid_1's l2: 0.572294
# [660]	training's rmse: 0.593516	training's l2: 0.352262	valid_1's rmse: 0.756531	valid_1's l2: 0.572339
# [670]	training's rmse: 0.59243	training's l2: 0.350973	valid_1's rmse: 0.756431	valid_1's l2: 0.572189
# [680]	training's rmse: 0.591333	training's l2: 0.349675	valid_1's rmse: 0.756275	valid_1's l2: 0.571953
# [690]	training's rmse: 0.590202	training's l2: 0.348338	valid_1's rmse: 0.756201	valid_1's l2: 0.57184
# [700]	training's rmse: 0.589136	training's l2: 0.347081	valid_1's rmse: 0.756222	valid_1's l2: 0.571872
# [710]	training's rmse: 0.588115	training's l2: 0.345879	valid_1's rmse: 0.756183	valid_1's l2: 0.571813
# [720]	training's rmse: 0.587187	training's l2: 0.344788	valid_1's rmse: 0.756151	valid_1's l2: 0.571765
# [730]	training's rmse: 0.586179	training's l2: 0.343606	valid_1's rmse: 0.756115	valid_1's l2: 0.571709
# [740]	training's rmse: 0.585114	training's l2: 0.342358	valid_1's rmse: 0.756144	valid_1's l2: 0.571753
# [750]	training's rmse: 0.584061	training's l2: 0.341128	valid_1's rmse: 0.756233	valid_1's l2: 0.571889
# [760]	training's rmse: 0.583046	training's l2: 0.339943	valid_1's rmse: 0.756304	valid_1's l2: 0.571995
# [770]	training's rmse: 0.58209	training's l2: 0.338829	valid_1's rmse: 0.756283	valid_1's l2: 0.571964
# [780]	training's rmse: 0.581208	training's l2: 0.337802	valid_1's rmse: 0.756342	valid_1's l2: 0.572054
# [790]	training's rmse: 0.580292	training's l2: 0.336739	valid_1's rmse: 0.756401	valid_1's l2: 0.572143
# [800]	training's rmse: 0.579451	training's l2: 0.335763	valid_1's rmse: 0.756416	valid_1's l2: 0.572165
# [810]	training's rmse: 0.578478	training's l2: 0.334637	valid_1's rmse: 0.756481	valid_1's l2: 0.572263
# [820]	training's rmse: 0.577627	training's l2: 0.333654	valid_1's rmse: 0.756428	valid_1's l2: 0.572183
# [830]	training's rmse: 0.576781	training's l2: 0.332676	valid_1's rmse: 0.756439	valid_1's l2: 0.572201
# Early stopping, best iteration is:
# [738]	training's rmse: 0.585358	training's l2: 0.342645	valid_1's rmse: 0.756106	valid_1's l2: 0.571696

# %%
_ = lgbm.plot_importance(booster, figsize=(10,40), height=0.5, importance_type="gain", ignore_zero=False)

# %%
print("finished everything!")

# %%
def plot_correlation_mat(cm, title='Feature correlations', figsize=(50,50)):
    fig, ax = plt.subplots(figsize=figsize)
    axsubplot = sns.heatmap(cm, annot=True, ax=ax)
    fig.tight_layout()

cm = matrix.corr()
plot_correlation_mat(cm)

# %%
# Create correlation matrix
corr_matrix = matrix.corr(method='spearman').abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Drop Marked Features
# Drop features 
df.drop(df[to_drop], axis=1)
